# %%
import pandas as pd
import numpy as np
import os

# pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
# pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %%
HOME_DIR = '/Users/summ7t/dev/novartis/table-linker/t2dv2-candidates-april-28/dev'

# %% [markdown]
# ### Generate lof-graph-embedding-score for any table
#
# Required datasets
# - candidate file
# - candidate feature file
# - graph_embedding_complex.tsv (generated and stored during candidate generation)
#
# Script used `lof-script.sh`
#
# ```
# filename=$1
# tsv_postfix=_graph_embedding_complex
#
# tl smallest-qnode-number train-candidates/candidates-$filename.csv \
# / align-page-rank \
# / string-similarity -i --method symmetric_monge_elkan:tokenizer=word -o monge_elkan \
# / string-similarity -i --method jaccard:tokenizer=word -c kg_descriptions context -o des_cont_jaccard \
# / normalize-scores -c des_cont_jaccard \
# / vote-by-classifier --prob-threshold 0.995 --model weighted_lr.pkl \
# > model-voted/$filename.csv
#
# tl score-using-embedding model-voted/$filename.csv \
# --column-vector-strategy centroid-of-lof \
# --lof-strategy ems-mv \
# -o graph-embedding-score \
# --embedding-file train-graph-embeddings/$filename$tsv_postfix.tsv \
# --embedding-url http://ckg07:9200/wikidatadwd-augmented/ \
# > lof-score/$filename.csv
# ```
#
# cmd: `bash {HOME_DIR}/lof-script.sh {fid}`
#
# output: lof-score/$filename.csv contains `is_lof` and `graph-embedding-score` (centroid-of-lof)

# %%
# !mkdir -p $HOME_DIR/model-voted
# !mkdir -p $HOME_DIR/lof-score
# !mkdir -p $HOME_DIR/merged-lof-score
# !mkdir -p $HOME_DIR/final-features

# %%
# list all files in candidates dir
file_names = []
file_ids = []

for (dirpath, dirnames, filenames) in os.walk(f'{HOME_DIR}/dev-candidates/'):
    for fn in filenames:
        if "csv" not in fn:
            continue
        abs_fn = dirpath + fn
        assert os.path.isfile(abs_fn)
        if os.path.getsize(abs_fn) == 0:
            continue
        file_names.append(abs_fn)
        file_ids.append(fn.split('.csv')[0].split('candidates-')[1])
len(file_names), file_ids[:3]
# Out:
# (9,
#  ['14380604_4_3329235705746762392',
#   '29414811_2_4773219892816395776',
#   '84575189_0_6365692015941409487'])

# %%
for idx, fid in enumerate(file_ids):
    print(f"Generating score for {idx}th file: {fid}...")
    os.system(f'bash {HOME_DIR}/lof-script.sh {fid}')
    assert os.path.isfile(f'{HOME_DIR}/model-voted/{fid}.csv'), f"Something wrong with model-voted result: {idx}th file: {fid}"
    assert os.path.isfile(f'{HOME_DIR}/lof-score/{fid}.csv'), f"Something wrong with lof-score result: {idx}th file: {fid}"
# Out:
# Generating score for 0th file: 14380604_4_3329235705746762392...
# Generating score for 1th file: 29414811_2_4773219892816395776...
# Generating score for 2th file: 84575189_0_6365692015941409487...
# Generating score for 3th file: 52299421_0_4473286348258170200...
# Generating score for 4th file: 28086084_0_3127660530989916727...
# Generating score for 5th file: 39759273_0_1427898308030295194...
# Generating score for 6th file: 45073662_0_3179937335063201739...
# Generating score for 7th file: 14067031_0_559833072073397908...
# Generating score for 8th file: 50270082_0_444360818941411589...

# %%
# check model-voted and lof-score files
fid = '14380604_4_3329235705746762392'
model_voted_df = pd.read_csv(f'{HOME_DIR}/model-voted/{fid}.csv')
model_voted_df[model_voted_df['vote_by_classifier'] > 0]
# Out:
#       column  row                         label  \
# 405        1    4          JPMorgan Chase & Co.
# 574        1    5  American International Group
# 606        1    6                    ExxonMobil
# 607        1    6                    ExxonMobil
# 1124       1   10                            BP
# 1152       1   10                            BP
# 2028       1   17                      Barclays
# 2031       1   17                      Barclays
#
#                                            context  \
# 405      5|USA|Banking|99.30|14.44|1,351.52|170.97
# 574     6|USA|Insurance|113.19|14.01|979.41|174.47
# 606   7|USA|Oil and gas|335.09|39.50|223.95|410.65
# 607   7|USA|Oil and gas|335.09|39.50|223.95|410.65
# 1124  11|UK|Oil and gas|265.91|22.29|217.60|198.14
# 1152  11|UK|Oil and gas|265.91|22.29|217.60|198.14
# 2028       18|UK|Banking|67.71|8.95|1,949.17|94.79
# 2031       18|UK|Banking|67.71|8.95|1,949.17|94.79
#
#                        label_clean    kg_id                     kg_labels  \
# 405           JPMorgan Chase   Co.  Q192314                JPMorgan Chase
# 574   American International Group    Q8774  International Airlines Group
# 606                     ExxonMobil  Q156238                    ExxonMobil
# 607                     ExxonMobil  Q156238                    ExxonMobil
# 1124                            BP  Q152057                            BP
# 1152                            BP  Q152057                            BP
# 2028                      Barclays  Q245343                      Barclays
# 2031                      Barclays  Q245343                      Barclays
#
#                                              kg_aliases           method  \
# 405   Bank of the Manhattan Company|JPMorgan Chase &...  fuzzy-augmented
# 574   International Consolidated Airlines Group SA|I...  fuzzy-augmented
# 606   Exxon|Exxon Mobil Corp.|Exxon Mobil|Exxon Mobi...      exact-match
# 607   Exxon|Exxon Mobil Corp.|Exxon Mobil|Exxon Mobi...  fuzzy-augmented
# 1124                BP P.L.C.|BP plc,|British Petroleum      exact-match
# 1152                BP P.L.C.|BP plc,|British Petroleum  fuzzy-augmented
# 2028             Barclays (United Kingdom)|Barclays PLC      exact-match
# 2031             Barclays (United Kingdom)|Barclays PLC  fuzzy-augmented
#
#                                         kg_descriptions      pagerank  \
# 405   American multinational banking and financial s...  1.038304e-07
# 574   British-Spanish multinational airline holding ...  4.579354e-08
# 606      American multinational oil and gas corporation  7.353359e-08
# 607      American multinational oil and gas corporation  7.353359e-08
# 1124          British multinational oil and gas company  1.013292e-07
# 1152          British multinational oil and gas company  1.013292e-07
# 2028  British multinational banking and financial se...  4.450382e-08
# 2031  British multinational banking and financial se...  4.450382e-08
#
#       retrieval_score  smallest_qnode_number  aligned_pagerank  monge_elkan  \
# 405         34.488980                      1      0.000000e+00     0.751111
# 574         15.741833                      1      0.000000e+00     0.894444
# 606         21.693314                      1      7.353359e-08     1.000000
# 607         21.561049                      1      0.000000e+00     1.000000
# 1124        18.212986                      0      1.013292e-07     1.000000
# 1152        16.176670                      0      0.000000e+00     1.000000
# 2028        20.621593                      1      4.450382e-08     1.000000
# 2031        18.983230                      1      0.000000e+00     1.000000
#
#       des_cont_jaccard  des_cont_jaccard_normalized  vote_by_classifier
# 405           0.125000                     0.208333                   1
# 574           0.000000                     0.000000                   1
# 606           0.500000                     1.000000                   1
# 607           0.500000                     0.833333                   1
# 1124          0.500000                     1.000000                   1
# 1152          0.500000                     0.833333                   1
# 2028          0.142857                     0.285714                   1
# 2031          0.142857                     0.238095                   1

# %%
fid = '14380604_4_3329235705746762392'
score_df = pd.read_csv(f'{HOME_DIR}/lof-score/{fid}.csv')
score_df.sort_values(by=['graph-embedding-score'], ascending=False).head(10)
# Out:
#       column  row                         label  \
# 171        1   10                            BP
# 199        1   10                            BP
# 1075       1   17                      Barclays
# 1078       1   17                      Barclays
# 1898       1    6                    ExxonMobil
# 1897       1    6                    ExxonMobil
# 0          1    0                     Citigroup
# 1          1    0                     Citigroup
# 1696       1    4          JPMorgan Chase & Co.
# 1797       1    5  American International Group
#
#                                            context  \
# 171   11|UK|Oil and gas|265.91|22.29|217.60|198.14
# 199   11|UK|Oil and gas|265.91|22.29|217.60|198.14
# 1075       18|UK|Banking|67.71|8.95|1,949.17|94.79
# 1078       18|UK|Banking|67.71|8.95|1,949.17|94.79
# 1898  7|USA|Oil and gas|335.09|39.50|223.95|410.65
# 1897  7|USA|Oil and gas|335.09|39.50|223.95|410.65
# 0       1|USA|Banking|146.56|21.54|1,884.32|247.42
# 1       1|USA|Banking|146.56|21.54|1,884.32|247.42
# 1696     5|USA|Banking|99.30|14.44|1,351.52|170.97
# 1797    6|USA|Insurance|113.19|14.01|979.41|174.47
#
#                        label_clean    kg_id                     kg_labels  \
# 171                             BP  Q152057                            BP
# 199                             BP  Q152057                            BP
# 1075                      Barclays  Q245343                      Barclays
# 1078                      Barclays  Q245343                      Barclays
# 1898                    ExxonMobil  Q156238                    ExxonMobil
# 1897                    ExxonMobil  Q156238                    ExxonMobil
# 0                        Citigroup  Q219508                     Citigroup
# 1                        Citigroup  Q219508                     Citigroup
# 1696          JPMorgan Chase   Co.  Q192314                JPMorgan Chase
# 1797  American International Group  Q212235  American International Group
#
#                                              kg_aliases           method  \
# 171                 BP P.L.C.|BP plc,|British Petroleum      exact-match
# 199                 BP P.L.C.|BP plc,|British Petroleum  fuzzy-augmented
# 1075             Barclays (United Kingdom)|Barclays PLC      exact-match
# 1078             Barclays (United Kingdom)|Barclays PLC  fuzzy-augmented
# 1898  Exxon|Exxon Mobil Corp.|Exxon Mobil|Exxon Mobi...  fuzzy-augmented
# 1897  Exxon|Exxon Mobil Corp.|Exxon Mobil|Exxon Mobi...      exact-match
# 0             City Bank of New York|Citigroup Inc.|Citi      exact-match
# 1             City Bank of New York|Citigroup Inc.|Citi  fuzzy-augmented
# 1696  Bank of the Manhattan Company|JPMorgan Chase &...  fuzzy-augmented
# 1797             AIG|American International Group, Inc.  fuzzy-augmented
#
#                                         kg_descriptions  ...  retrieval_score  \
# 171           British multinational oil and gas company  ...        18.212986
# 199           British multinational oil and gas company  ...        16.176670
# 1075  British multinational banking and financial se...  ...        20.621593
# 1078  British multinational banking and financial se...  ...        18.983230
# 1898     American multinational oil and gas corporation  ...        21.561049
# 1897     American multinational oil and gas corporation  ...        21.693314
# 0     American investment bank and financial service...  ...        21.693314
# 1     American investment bank and financial service...  ...        19.263160
# 1696  American multinational banking and financial s...  ...        34.488980
# 1797       American multinational insurance corporation  ...        28.054087
#
#       smallest_qnode_number  aligned_pagerank  monge_elkan  des_cont_jaccard  \
# 171                       0      1.013292e-07     1.000000          0.500000
# 199                       0      0.000000e+00     1.000000          0.500000
# 1075                      1      4.450382e-08     1.000000          0.142857
# 1078                      1      0.000000e+00     1.000000          0.142857
# 1898                      1      0.000000e+00     1.000000          0.500000
# 1897                      1      7.353359e-08     1.000000          0.500000
# 0                         0      8.027813e-08     1.000000          0.000000
# 1                         0      0.000000e+00     1.000000          0.000000
# 1696                      1      0.000000e+00     0.751111          0.125000
# 1797                      0      0.000000e+00     1.000000          0.250000
#
#       des_cont_jaccard_normalized  vote_by_classifier  singleton  is_lof  \
# 171                      1.000000                   1          0       1
# 199                      0.833333                   1          0       1
# 1075                     0.285714                   1          0       1
# 1078                     0.238095                   1          0       1
# 1898                     0.833333                   1          0       1
# 1897                     1.000000                   1          1       1
# 0                        0.000000                   0          1       1
# 1                        0.000000                   0          0      -1
# 1696                     0.208333                   1          0      -1
# 1797                     0.416667                   0          0      -1
#
#       graph-embedding-score
# 171                0.885915
# 199                0.885915
# 1075               0.863573
# 1078               0.863573
# 1898               0.843475
# 1897               0.843475
# 0                  0.811528
# 1                  0.811528
# 1696               0.792447
# 1797               0.789462
#
# [10 rows x 21 columns]

# %%
# merge lof candidate (graph-embedding-score) with candidate feature file
for idx, fid in enumerate(file_ids):
    print(f"Merging embedding score for {idx}th file: {fid}...")
    features_df = pd.read_csv(f'{HOME_DIR}/dev-features/{fid}.csv')
    lof_score_df = pd.read_csv(f'{HOME_DIR}/lof-score/{fid}.csv')
    lof_score_df.rename(columns = {'graph-embedding-score':'lof-graph-embedding-score'}, inplace = True)
    trimmed_lof_score_df = lof_score_df.loc[:, ['column', 'row', 'kg_id', 'method', 'lof-graph-embedding-score', 'is_lof']]
    
    # merge two df on row, column, kg_id
    final_df = pd.merge(features_df, trimmed_lof_score_df, left_on=['column', 'row', 'kg_id', 'method'], right_on = ['column', 'row', 'kg_id', 'method'])
    final_df.drop_duplicates(inplace=True)
    assert len(final_df) == len(features_df), f"{len(features_df)}, {len(final_df)}"
    
    final_df.to_csv(f"{HOME_DIR}/merged-lof-score/{fid}.csv", index=False)
    assert os.path.isfile(f'{HOME_DIR}/merged-lof-score/{fid}.csv'), f"Something wrong with merged score result: {idx}th file: {fid}"

# %%
# check merged train feature files
fid = '14380604_4_3329235705746762392'
merged_score_df = pd.read_csv(f'{HOME_DIR}/merged-lof-score/{fid}.csv')
# merged_score_df.sort_values(by=['lof-graph-embedding-score'], ascending=False).head(10)
merged_score_df[merged_score_df['is_lof'] == 1]
# Out:
#       column  row                         label  \
# 57         1    0                     Citigroup
# 176        1   10                            BP
# 311        1   10                            BP
# 1075       1   17                      Barclays
# 1220       1   17                      Barclays
# 1896       1    5  American International Group
# 1897       1    6                    ExxonMobil
# 1997       1    6                    ExxonMobil
#
#                                            context  \
# 57      1|USA|Banking|146.56|21.54|1,884.32|247.42
# 176   11|UK|Oil and gas|265.91|22.29|217.60|198.14
# 311   11|UK|Oil and gas|265.91|22.29|217.60|198.14
# 1075       18|UK|Banking|67.71|8.95|1,949.17|94.79
# 1220       18|UK|Banking|67.71|8.95|1,949.17|94.79
# 1896    6|USA|Insurance|113.19|14.01|979.41|174.47
# 1897  7|USA|Oil and gas|335.09|39.50|223.95|410.65
# 1997  7|USA|Oil and gas|335.09|39.50|223.95|410.65
#
#                        label_clean    kg_id                     kg_labels  \
# 57                       Citigroup  Q219508                     Citigroup
# 176                             BP  Q152057                            BP
# 311                             BP  Q152057                            BP
# 1075                      Barclays  Q245343                      Barclays
# 1220                      Barclays  Q245343                      Barclays
# 1896  American International Group  Q212235  American International Group
# 1897                    ExxonMobil  Q156238                    ExxonMobil
# 1997                    ExxonMobil  Q156238                    ExxonMobil
#
#                                                        kg_aliases  \
# 57                      City Bank of New York|Citigroup Inc.|Citi
# 176                           BP P.L.C.|BP plc,|British Petroleum
# 311                           BP P.L.C.|BP plc,|British Petroleum
# 1075                       Barclays (United Kingdom)|Barclays PLC
# 1220                       Barclays (United Kingdom)|Barclays PLC
# 1896                       AIG|American International Group, Inc.
# 1897  Exxon|Exxon Mobil Corp.|Exxon Mobil|Exxon Mobil Corporation
# 1997  Exxon|Exxon Mobil Corp.|Exxon Mobil|Exxon Mobil Corporation
#
#                method  \
# 57        exact-match
# 176   fuzzy-augmented
# 311       exact-match
# 1075  fuzzy-augmented
# 1220      exact-match
# 1896      exact-match
# 1897  fuzzy-augmented
# 1997      exact-match
#
#                                                    kg_descriptions  \
# 57     American investment bank and financial services corporation
# 176                      British multinational oil and gas company
# 311                      British multinational oil and gas company
# 1075  British multinational banking and financial services company
# 1220  British multinational banking and financial services company
# 1896                  American multinational insurance corporation
# 1897                American multinational oil and gas corporation
# 1997                American multinational oil and gas corporation
#
#           pagerank  retrieval_score GT_kg_id                   GT_kg_label  \
# 57    8.027813e-08        21.693314  Q219508                     Citigroup
# 176   1.013292e-07        16.176670  Q152057                            bp
# 311   1.013292e-07        18.212986  Q152057                            bp
# 1075  4.450382e-08        18.983230  Q245343                      Barclays
# 1220  4.450382e-08        20.621593  Q245343                      Barclays
# 1896  1.831754e-08        21.693314  Q212235  American International Group
# 1897  7.353359e-08        21.561049  Q156238                    ExxonMobil
# 1997  7.353359e-08        21.693314  Q156238                    ExxonMobil
#
#       evaluation_label  monge_elkan  des_cont_jaccard  jaro_winkler  \
# 57                   1          1.0          0.000000           1.0
# 176                  1          1.0          0.500000           1.0
# 311                  1          1.0          0.500000           1.0
# 1075                 1          1.0          0.142857           1.0
# 1220                 1          1.0          0.142857           1.0
# 1896                 1          1.0          0.250000           1.0
# 1897                 1          1.0          0.500000           1.0
# 1997                 1          1.0          0.500000           1.0
#
#       graph-embedding-score  singleton  reciprocal_rank  num_char  num_tokens  \
# 57                 0.841920          1              0.5         9           1
# 176                0.745220          0              1.0         2           1
# 311                0.745220          0              0.5         2           1
# 1075               0.770165          0              1.0         8           1
# 1220               0.770165          0              0.5         8           1
# 1896               0.814121          1              0.5        28           3
# 1897               0.824170          0              1.0        10           1
# 1997               0.824170          1              0.5        10           1
#
#       class_count_tf_idf_score  property_count_tf_idf_score  \
# 57                    0.445131                     0.575829
# 176                   0.349661                     0.531144
# 311                   0.349661                     0.531144
# 1075                  0.598094                     0.431890
# 1220                  0.598094                     0.431890
# 1896                  0.349661                     0.335018
# 1897                  0.620813                     0.550966
# 1997                  0.620813                     0.550966
#
#       lof-graph-embedding-score  is_lof
# 57                     0.811528       1
# 176                    0.885915       1
# 311                    0.885915       1
# 1075                   0.863573       1
# 1220                   0.863573       1
# 1896                   0.789462       1
# 1897                   0.843475       1
# 1997                   0.843475       1

# %%
# Generate lof-reciprocal-rank
for idx, fid in enumerate(file_ids):
    print(f"generating final feature for {idx}th file: {fid}")
    class_count_f = f'{HOME_DIR}/dev-class-count/{fid}_class_count.tsv'
    property_count_f = f'{HOME_DIR}/dev-prop-count/{fid}_prop_count.tsv'
    merged_lof_f = f'{HOME_DIR}/merged-lof-score/{fid}.csv'
    final_features_f = f'{HOME_DIR}/final-features/{fid}.csv'
    script = f"""
    tl generate-reciprocal-rank {merged_lof_f} \
    -c lof-graph-embedding-score \
    -o lof-reciprocal-rank \
    / compute-tf-idf \
    --feature-file {class_count_f} \
    --feature-name class_count \
    --singleton-column is_lof \
    -o lof_class_count_tf_idf_score \
    / compute-tf-idf \
    --feature-file {property_count_f} \
    --feature-name property_count \
    --singleton-column is_lof \
    -o lof_property_count_tf_idf_score \
    > {final_features_f}
    """
    os.system(script)
    assert os.path.isfile(final_features_f), f"Something wrong with final feature result: {idx}th file: {fid}"
# Out:
# generating final feature for 0th file: 14380604_4_3329235705746762392
# generating final feature for 1th file: 29414811_2_4773219892816395776
# generating final feature for 2th file: 84575189_0_6365692015941409487
# generating final feature for 3th file: 52299421_0_4473286348258170200
# generating final feature for 4th file: 28086084_0_3127660530989916727
# generating final feature for 5th file: 39759273_0_1427898308030295194
# generating final feature for 6th file: 45073662_0_3179937335063201739
# generating final feature for 7th file: 14067031_0_559833072073397908
# generating final feature for 8th file: 50270082_0_444360818941411589

# %%
#     / compute-tf-idf \
#     --feature-file {class_count_f} \
#     --feature-name class_count \
#     --singleton-column singleton \
#     -o cos_class_count_tf_idf_score \
#     / compute-tf-idf \
#     --feature-file {property_count_f} \
#     --feature-name property_count \
#     --singleton-column singleton \
#     -o cos_property_count_tf_idf_score \

# %%
# check final feature files
fid = '84575189_0_6365692015941409487'
final_feature_df = pd.read_csv(f'{HOME_DIR}/final-features/{fid}.csv')
final_feature_df[final_feature_df['evaluation_label'] == 1].loc[:, [
    'property_count_tf_idf_score', 'lof_property_count_tf_idf_score',
    'class_count_tf_idf_score', 'lof_class_count_tf_idf_score'
]]
# Out:
#        property_count_tf_idf_score  lof_property_count_tf_idf_score  \
# 12                        0.322198                         0.220705
# 188                       0.322198                         0.220705
# 213                       0.390072                         0.287844
# 378                       0.390072                         0.287844
# 401                       0.183688                         0.131269
# ...                            ...                              ...
# 10656                     0.169593                         0.126814
# 10657                     0.094882                         0.070949
# 10758                     0.276941                         0.201190
# 10857                     0.276941                         0.201190
# 10861                     0.195786                         0.146400
#
#        class_count_tf_idf_score  lof_class_count_tf_idf_score
# 12                     0.187615                      0.155264
# 188                    0.187615                      0.155264
# 213                    0.187615                      0.155264
# 378                    0.187615                      0.155264
# 401                    0.671224                      0.555484
# ...                         ...                           ...
# 10656                  0.435872                      0.360714
# 10657                  0.187615                      0.155264
# 10758                  0.125635                      0.103971
# 10857                  0.125635                      0.103971
# 10861                  0.694271                      0.574556
#
# [172 rows x 4 columns]

# %%
len(final_feature_df.groupby(['column', 'row']))
# Out:
# 100

# %%
len(final_feature_df[final_feature_df['is_lof'] == 1]), \
len(final_feature_df[(final_feature_df['is_lof'] == 1) & (final_feature_df['evaluation_label'] == 1)]), \
len(final_feature_df[final_feature_df['singleton'] == 1]), \
len(final_feature_df[(final_feature_df['singleton'] == 1) & (final_feature_df['evaluation_label'] == 1)])
# Out:
# (46, 33, 57, 54)

# %%
final_feature_df.sort_values(by=['class_count_tf_idf_score'], ascending=False).head(10)
# Out:
#       column  row                                                      label  \
# 7838       2   74                                        Genes & Development
# 8108       2   76                      Antimicrobial Agents and Chemotherapy
# 8008       2   76                      Antimicrobial Agents and Chemotherapy
# 3709       2   39                               Journal of Molecular Biology
# 7551       2   71  The Journal of Pharmacology And Experimental Therapeutics
# 9311       2   84         The Journal of Clinical Endocrinology & Metabolism
# 7222       2   69                                           Human Immunology
# 3213       2   36                                The Journal of Bacteriology
# 9248       2   84         The Journal of Clinical Endocrinology & Metabolism
# 2464       2   29                 The American Journal of Clinical Nutrition
#
#      context                                                label_clean  \
# 7838   75|93                                        Genes   Development
# 8108   77|91                      Antimicrobial Agents and Chemotherapy
# 8008   77|91                      Antimicrobial Agents and Chemotherapy
# 3709  40|162                               Journal of Molecular Biology
# 7551   72|98  The Journal of Pharmacology And Experimental Therapeutics
# 9311   85|85         The Journal of Clinical Endocrinology   Metabolism
# 7222  70|102                                           Human Immunology
# 3213  37|165                                The Journal of Bacteriology
# 9248   85|85         The Journal of Clinical Endocrinology   Metabolism
# 2464  30|185                 The American Journal of Clinical Nutrition
#
#           kg_id                                   kg_labels  \
# 7838    Q112067                   Genes, Brain and Behavior
# 8108    Q578004       Antimicrobial Agents and Chemotherapy
# 8008    Q578004       Antimicrobial Agents and Chemotherapy
# 3709   Q1524048                Journal of Leukocyte Biology
# 7551    Q176044    British Journal of Clinical Pharmacology
# 9311  Q15745208  European Journal of Clinical Investigation
# 7222  Q13731918                   Immunology & Cell Biology
# 3213    Q400296                    The Journal of Pathology
# 9248   Q3186904           Journal of Clinical Investigation
# 2464   Q2842959            The American Journal of Medicine
#
#                                                                                                                                   kg_aliases  \
# 7838                                                                                                                  G2B|Genes Brain Behav.
# 8108  Antimicrobial agents and chemotherapy|Antimicrob Agents Chemother (Bethesda)|Antimicrob Agents Chemother|Antimicrob. Agents Chemother.
# 8008  Antimicrobial agents and chemotherapy|Antimicrob Agents Chemother (Bethesda)|Antimicrob Agents Chemother|Antimicrob. Agents Chemother.
# 3709                                                                                                          J. Leukoc. Biol.|J Leukoc Biol
# 7551                                                                                            Br. J. Clin. Pharmacol.|Br J Clin Pharmacol.
# 9311                                                                                                                                     NaN
# 7222                                                                                                             Immunology and Cell Biology
# 3213                                                                                                                    Journal of Pathology
# 9248                                                                    The journal of clinical investigation|J. Clin. Invest.|J Clin Invest
# 2464                                                                                                            American Journal of Medicine
#
#                method                   kg_descriptions      pagerank  \
# 7838  fuzzy-augmented                Scientific journal  3.539613e-09
# 8108      exact-match                scientific journal  3.539613e-09
# 8008  fuzzy-augmented                scientific journal  3.539613e-09
# 3709  fuzzy-augmented                scientific journal  4.445894e-09
# 7551  fuzzy-augmented                scientific journal  4.492359e-09
# 9311  fuzzy-augmented                           journal  3.539613e-09
# 7222  fuzzy-augmented                scientific journal  3.539613e-09
# 3213  fuzzy-augmented  peer-reviewed scientific journal  3.539613e-09
# 9248  fuzzy-augmented  peer-reviewed scientific journal  4.542504e-09
# 2464  fuzzy-augmented                           journal  3.631214e-09
#
#       retrieval_score   GT_kg_id  \
# 7838        15.829847   Q1524533
# 8108        21.693314    Q578004
# 8008        50.660416    Q578004
# 3709        22.634863    Q925779
# 7551        23.825903   Q1500272
# 9311        21.430408   Q3186902
# 7222        15.896554  Q15709955
# 3213        26.566677    Q478419
# 9248        24.363552   Q3186902
# 2464        22.533007   Q7713500
#
#                                                 GT_kg_label  evaluation_label  \
# 7838                                    Genes & Development                -1
# 8108                  Antimicrobial Agents and Chemotherapy                 1
# 8008                  Antimicrobial Agents and Chemotherapy                 1
# 3709                           Journal of Molecular Biology                -1
# 7551  Journal of Pharmacology and Experimental Therapeutics                -1
# 9311   The Journal of Clinical Endocrinology and Metabolism                -1
# 7222                                       Human Immunology                -1
# 3213                                Journal of Bacteriology                -1
# 9248   The Journal of Clinical Endocrinology and Metabolism                -1
# 2464             The American Journal of Clinical Nutrition                -1
#
#       monge_elkan  des_cont_jaccard  jaro_winkler  graph-embedding-score  \
# 7838     0.501199               0.0      0.642679               0.830504
# 8108     1.000000               0.0      1.000000               0.825053
# 8008     1.000000               0.0      1.000000               0.825053
# 3709     0.894874               0.0      0.909524               0.829085
# 7551     0.739087               0.0      0.630885               0.775199
# 9311     0.710816               0.0      0.713492               0.872266
# 7222     0.607937               0.0      0.557652               0.897541
# 3213     0.946759               0.0      0.946296               0.868306
# 9248     0.736237               0.0      0.648066               0.839285
# 2464     0.905886               0.0      0.894048               0.806349
#
#       singleton  reciprocal_rank  num_char  num_tokens  \
# 7838          0         0.166667        25           4
# 8108          1         0.111111        37           4
# 8008          0         0.125000        37           4
# 3709          0         0.033333        28           4
# 7551          0         0.016129        40           5
# 9311          0         0.045455        42           5
# 7222          0         0.333333        25           4
# 3213          0         0.142857        24           4
# 9248          0         0.023810        33           4
# 2464          0         0.017241        32           5
#
#       class_count_tf_idf_score  property_count_tf_idf_score  \
# 7838                  0.922595                     0.182474
# 8108                  0.905342                     0.218164
# 8008                  0.905342                     0.218164
# 3709                  0.899549                     0.193976
# 7551                  0.899549                     0.208187
# 9311                  0.899549                     0.156670
# 7222                  0.899549                     0.137520
# 3213                  0.899549                     0.194082
# 9248                  0.899549                     0.215837
# 2464                  0.899549                     0.208783
#
#       lof-graph-embedding-score  is_lof  lof-reciprocal-rank  \
# 7838                   0.811784      -1             0.333333
# 8108                   0.776517       1             0.166667
# 8008                   0.776517      -1             0.200000
# 3709                   0.749735      -1             0.030303
# 7551                   0.685951      -1             0.014286
# 9311                   0.799611      -1             0.071429
# 7222                   0.833978      -1             0.500000
# 3213                   0.801616      -1             0.333333
# 9248                   0.767367      -1             0.027778
# 2464                   0.719791      -1             0.016667
#
#       lof_class_count_tf_idf_score  lof_property_count_tf_idf_score
# 7838                      0.763510                         0.136446
# 8108                      0.749232                         0.163133
# 8008                      0.749232                         0.163133
# 3709                      0.744438                         0.145046
# 7551                      0.744438                         0.155673
# 9311                      0.744438                         0.117151
# 7222                      0.744438                         0.102831
# 3213                      0.744438                         0.145125
# 9248                      0.744438                         0.161394
# 2464                      0.744438                         0.156119

# %%
final_feature_df.sort_values(by=['lof_class_count_tf_idf_score'], ascending=False).head(10)
# Out:
#       column  row                                               label context  \
# 7838       2   74                                 Genes & Development   75|93
# 8008       2   76               Antimicrobial Agents and Chemotherapy   77|91
# 8108       2   76               Antimicrobial Agents and Chemotherapy   77|91
# 9317       2   84  The Journal of Clinical Endocrinology & Metabolism   85|85
# 9248       2   84  The Journal of Clinical Endocrinology & Metabolism   85|85
# 5067       2   50                       Biochimica et Biophysica Acta  51|128
# 7668       2   72                    Journal of Clinical Microbiology   73|96
# 7662       2   72                    Journal of Clinical Microbiology   73|96
# 3213       2   36                         The Journal of Bacteriology  37|165
# 4719       2   48               The Journal of Clinical Investigation  49|129
#
#                                              label_clean      kg_id  \
# 7838                                 Genes   Development    Q112067
# 8008               Antimicrobial Agents and Chemotherapy    Q578004
# 8108               Antimicrobial Agents and Chemotherapy    Q578004
# 9317  The Journal of Clinical Endocrinology   Metabolism    Q176044
# 9248  The Journal of Clinical Endocrinology   Metabolism   Q3186904
# 5067                       Biochimica et Biophysica Acta   Q4676737
# 7668                    Journal of Clinical Microbiology    Q176044
# 7662                    Journal of Clinical Microbiology  Q15745208
# 3213                         The Journal of Bacteriology    Q400296
# 4719               The Journal of Clinical Investigation  Q15745208
#
#                                           kg_labels  \
# 7838                      Genes, Brain and Behavior
# 8008          Antimicrobial Agents and Chemotherapy
# 8108          Antimicrobial Agents and Chemotherapy
# 9317       British Journal of Clinical Pharmacology
# 9248              Journal of Clinical Investigation
# 5067  Acta Obstetricia et Gynecologica Scandinavica
# 7668       British Journal of Clinical Pharmacology
# 7662     European Journal of Clinical Investigation
# 3213                       The Journal of Pathology
# 4719     European Journal of Clinical Investigation
#
#                                                                                                                                   kg_aliases  \
# 7838                                                                                                                  G2B|Genes Brain Behav.
# 8008  Antimicrobial agents and chemotherapy|Antimicrob Agents Chemother (Bethesda)|Antimicrob Agents Chemother|Antimicrob. Agents Chemother.
# 8108  Antimicrobial agents and chemotherapy|Antimicrob Agents Chemother (Bethesda)|Antimicrob Agents Chemother|Antimicrob. Agents Chemother.
# 9317                                                                                            Br. J. Clin. Pharmacol.|Br J Clin Pharmacol.
# 9248                                                                    The journal of clinical investigation|J. Clin. Invest.|J Clin Invest
# 5067                                                                                                                                     NaN
# 7668                                                                                            Br. J. Clin. Pharmacol.|Br J Clin Pharmacol.
# 7662                                                                                                                                     NaN
# 3213                                                                                                                    Journal of Pathology
# 4719                                                                                                                                     NaN
#
#                method                   kg_descriptions      pagerank  \
# 7838  fuzzy-augmented                Scientific journal  3.539613e-09
# 8008  fuzzy-augmented                scientific journal  3.539613e-09
# 8108      exact-match                scientific journal  3.539613e-09
# 9317  fuzzy-augmented                scientific journal  4.492359e-09
# 9248  fuzzy-augmented  peer-reviewed scientific journal  4.542504e-09
# 5067  fuzzy-augmented  peer-reviewed scientific journal  3.539613e-09
# 7668  fuzzy-augmented                scientific journal  4.492359e-09
# 7662  fuzzy-augmented                           journal  3.539613e-09
# 3213  fuzzy-augmented  peer-reviewed scientific journal  3.539613e-09
# 4719  fuzzy-augmented                           journal  3.539613e-09
#
#       retrieval_score  GT_kg_id  \
# 7838        15.829847  Q1524533
# 8008        50.660416   Q578004
# 8108        21.693314   Q578004
# 9317        21.430408  Q3186902
# 9248        24.363552  Q3186902
# 5067        21.003864   Q864239
# 7668        21.430408  Q4041880
# 7662        21.430408  Q4041880
# 3213        26.566677   Q478419
# 4719        31.789219  Q3186904
#
#                                                GT_kg_label  evaluation_label  \
# 7838                                   Genes & Development                -1
# 8008                 Antimicrobial Agents and Chemotherapy                 1
# 8108                 Antimicrobial Agents and Chemotherapy                 1
# 9317  The Journal of Clinical Endocrinology and Metabolism                -1
# 9248  The Journal of Clinical Endocrinology and Metabolism                -1
# 5067                         Biochimica et Biophysica Acta                -1
# 7668                      Journal of Clinical Microbiology                -1
# 7662                      Journal of Clinical Microbiology                -1
# 3213                               Journal of Bacteriology                -1
# 4719                     Journal of Clinical Investigation                -1
#
#       monge_elkan  des_cont_jaccard  jaro_winkler  graph-embedding-score  \
# 7838     0.501199               0.0      0.642679               0.830504
# 8008     1.000000               0.0      1.000000               0.825053
# 8108     1.000000               0.0      1.000000               0.825053
# 9317     0.710099               0.0      0.666717               0.775199
# 9248     0.736237               0.0      0.648066               0.839285
# 5067     0.788510               0.0      0.597655               0.802834
# 7668     0.882440               0.0      0.740278               0.775199
# 7662     0.865871               0.0      0.669490               0.872266
# 3213     0.946759               0.0      0.946296               0.868306
# 4719     0.911651               0.0      0.774045               0.872266
#
#       singleton  reciprocal_rank  num_char  num_tokens  \
# 7838          0         0.166667        25           4
# 8008          0         0.125000        37           4
# 8108          1         0.111111        37           4
# 9317          0         0.013699        40           5
# 9248          0         0.023810        33           4
# 5067          0         0.034483        45           5
# 7668          0         0.013514        40           5
# 7662          0         0.043478        42           5
# 3213          0         0.142857        24           4
# 4719          0         0.043478        42           5
#
#       class_count_tf_idf_score  property_count_tf_idf_score  \
# 7838                  0.922595                     0.182474
# 8008                  0.905342                     0.218164
# 8108                  0.905342                     0.218164
# 9317                  0.899549                     0.208187
# 9248                  0.899549                     0.215837
# 5067                  0.899549                     0.171279
# 7668                  0.899549                     0.208187
# 7662                  0.899549                     0.156670
# 3213                  0.899549                     0.194082
# 4719                  0.899549                     0.156670
#
#       lof-graph-embedding-score  is_lof  lof-reciprocal-rank  \
# 7838                   0.811784      -1             0.333333
# 8008                   0.776517      -1             0.200000
# 8108                   0.776517       1             0.166667
# 9317                   0.685951      -1             0.012821
# 9248                   0.767367      -1             0.027778
# 5067                   0.727653      -1             0.055556
# 7668                   0.685951      -1             0.012195
# 7662                   0.799611      -1             0.062500
# 3213                   0.801616      -1             0.333333
# 4719                   0.799611      -1             0.062500
#
#       lof_class_count_tf_idf_score  lof_property_count_tf_idf_score
# 7838                      0.763510                         0.136446
# 8008                      0.749232                         0.163133
# 8108                      0.749232                         0.163133
# 9317                      0.744438                         0.155673
# 9248                      0.744438                         0.161394
# 5067                      0.744438                         0.128075
# 7668                      0.744438                         0.155673
# 7662                      0.744438                         0.117151
# 3213                      0.744438                         0.145125
# 4719                      0.744438                         0.117151

# %%
# final_feature_df[final_feature_df['evaluation_label'] == 1].loc[:, [
#     'cos_property_count_tf_idf_score', 'lof_property_count_tf_idf_score',
#     'cos_class_count_tf_idf_score', 'lof_class_count_tf_idf_score'
# ]]

# %%
# final_feature_df[final_feature_df['evaluation_label'] == 1].loc[:, [
#     'cos_class_count_tf_idf_score_tf', 'cos_class_count_tf_idf_score_idf',
#     'lof_class_count_tf_idf_score_tf', 'lof_class_count_tf_idf_score_idf'
# ]]

# %%
# final_feature_df[final_feature_df['evaluation_label'] == 1].loc[:, [
#     'cos_property_count_tf_idf_score_tf', 'cos_property_count_tf_idf_score_idf',
#     'lof_property_count_tf_idf_score_tf', 'lof_property_count_tf_idf_score_idf'
# ]]

# %% [markdown]
# ### Evaluation of lof-graph-embedding-score
# - baseline: graph-embedding-score (centroid-of-singleton)

# %%
# use top 1/5 accuracy
def embedding_eval(eval_file):
    assert "graph-embedding-score" in eval_file
    assert "lof-graph-embedding-score" in eval_file
    
    cos_top1_count = 0
    cos_top5_count = 0
    lof_top1_count = 0
    lof_top5_count = 0
    all_count = 0
    
    for ((col, row), group) in eval_file.groupby(['column', 'row']):
        all_count += 1
        
        # sort by centroid-of-singleton embedding score
        eval_labels = group.sort_values(by=['graph-embedding-score'], ascending=False)['evaluation_label']
        if eval_labels.iloc[0] == 1:
            cos_top1_count += 1
        if 1 in eval_labels.iloc[:5].values:
            cos_top5_count += 1
            
        # sort by centroid-of-lof embedding score
        eval_labels = group.sort_values(by=['lof-graph-embedding-score'], ascending=False)['evaluation_label']
        if eval_labels.iloc[0] == 1:
            lof_top1_count += 1
        if 1 in eval_labels.iloc[:5].values:
            lof_top5_count += 1
    
    return {
        'cos_top1_accuracy': cos_top1_count / all_count, 
        'cos_top5_accuracy': cos_top5_count / all_count, 
        'lof_top1_accuracy': lof_top1_count / all_count, 
        'lof_top5_accuracy': lof_top5_count / all_count,
        'all_count': all_count
    }

# %%
res_top_accuracy = {}
for fid in file_ids:
    final_df = pd.read_csv(f"{HOME_DIR}/merged-lof-score/{fid}.csv")
    res_top_accuracy[fid] = embedding_eval(final_df)
res_top_accuracy
# Out:
# {'14380604_4_3329235705746762392': {'cos_top1_accuracy': 0.7,
#   'cos_top5_accuracy': 0.9,
#   'lof_top1_accuracy': 0.75,
#   'lof_top5_accuracy': 0.9,
#   'all_count': 20},
#  '29414811_2_4773219892816395776': {'cos_top1_accuracy': 0.13636363636363635,
#   'cos_top5_accuracy': 0.5,
#   'lof_top1_accuracy': 0.045454545454545456,
#   'lof_top5_accuracy': 0.36363636363636365,
#   'all_count': 22},
#  '84575189_0_6365692015941409487': {'cos_top1_accuracy': 0.11,
#   'cos_top5_accuracy': 0.23,
#   'lof_top1_accuracy': 0.15,
#   'lof_top5_accuracy': 0.37,
#   'all_count': 100},
#  '52299421_0_4473286348258170200': {'cos_top1_accuracy': 0.0,
#   'cos_top5_accuracy': 0.0,
#   'lof_top1_accuracy': 0.8586956521739131,
#   'lof_top5_accuracy': 0.8804347826086957,
#   'all_count': 92},
#  '28086084_0_3127660530989916727': {'cos_top1_accuracy': 0.23660714285714285,
#   'cos_top5_accuracy': 0.5223214285714286,
#   'lof_top1_accuracy': 0.27232142857142855,
#   'lof_top5_accuracy': 0.5535714285714286,
#   'all_count': 224},
#  '39759273_0_1427898308030295194': {'cos_top1_accuracy': 0.58,
#   'cos_top5_accuracy': 0.93,
#   'lof_top1_accuracy': 0.65,
#   'lof_top5_accuracy': 0.96,
#   'all_count': 100},
#  '45073662_0_3179937335063201739': {'cos_top1_accuracy': 0.4074074074074074,
#   'cos_top5_accuracy': 0.8888888888888888,
#   'lof_top1_accuracy': 0.4444444444444444,
#   'lof_top5_accuracy': 0.8888888888888888,
#   'all_count': 27},
#  '14067031_0_559833072073397908': {'cos_top1_accuracy': 0.8867924528301887,
#   'cos_top5_accuracy': 0.9433962264150944,
#   'lof_top1_accuracy': 0.9433962264150944,
#   'lof_top5_accuracy': 0.9433962264150944,
#   'all_count': 53},
#  '50270082_0_444360818941411589': {'cos_top1_accuracy': 0.5476190476190477,
#   'cos_top5_accuracy': 0.9226190476190477,
#   'lof_top1_accuracy': 0.5297619047619048,
#   'lof_top5_accuracy': 0.9166666666666666,
#   'all_count': 168}}

# %%
top_accuracy_df = pd.DataFrame(res_top_accuracy)
top_accuracy_df = top_accuracy_df.transpose()
len(top_accuracy_df[top_accuracy_df['lof_top1_accuracy'] < top_accuracy_df['cos_top1_accuracy']]), \
len(top_accuracy_df[top_accuracy_df['lof_top5_accuracy'] < top_accuracy_df['cos_top5_accuracy']]), \
len(top_accuracy_df)
# Out:
# (2, 2, 9)

# %%
# visualize embedding-score difference
def highlight_greaterthan_1(x):
    if x.lof_top1_accuracy < x.cos_top1_accuracy:
        return ['background-color: yellow']*5
    else:
        return ['background-color: white']*5
    
top_accuracy_df.style.apply(highlight_greaterthan_1, axis=1)
# Out:
# <style  type="text/css" >
# #T_2e08d_row0_col0,#T_2e08d_row0_col1,#T_2e08d_row0_col2,#T_2e08d_row0_col3,#T_2e08d_row0_col4,#T_2e08d_row2_col0,#T_2e08d_row2_col1,#T_2e08d_row2_col2,#T_2e08d_row2_col3,#T_2e08d_row2_col4,#T_2e08d_row3_col0,#T_2e08d_row3_col1,#T_2e08d_row3_col2,#T_2e08d_row3_col3,#T_2e08d_row3_col4,#T_2e08d_row4_col0,#T_2e08d_row4_col1,#T_2e08d_row4_col2,#T_2e08d_row4_col3,#T_2e08d_row4_col4,#T_2e08d_row5_col0,#T_2e08d_row5_col1,#T_2e08d_row5_col2,#T_2e08d_row5_col3,#T_2e08d_row5_col4,#T_2e08d_row6_col0,#T_2e08d_row6_col1,#T_2e08d_row6_col2,#T_2e08d_row6_col3,#T_2e08d_row6_col4,#T_2e08d_row7_col0,#T_2e08d_row7_col1,#T_2e08d_row7_col2,#T_2e08d_row7_col3,#T_2e08d_row7_col4{
#             background-color:  white;
#         }#T_2e08d_row1_col0,#T_2e08d_row1_col1,#T_2e08d_row1_col2,#T_2e08d_row1_col3,#T_2e08d_row1_col4,#T_2e08d_row8_col0,#T_2e08d_row8_col1,#T_2e08d_row8_col2,#T_2e08d_row8_col3,#T_2e08d_row8_col4{
#             background-color:  yellow;
#         }</style><table id="T_2e08d_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >cos_top1_accuracy</th>        <th class="col_heading level0 col1" >cos_top5_accuracy</th>        <th class="col_heading level0 col2" >lof_top1_accuracy</th>        <th class="col_heading level0 col3" >lof_top5_accuracy</th>        <th class="col_heading level0 col4" >all_count</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2e08d_level0_row0" class="row_heading level0 row0" >14380604_4_3329235705746762392</th>
#                         <td id="T_2e08d_row0_col0" class="data row0 col0" >0.700000</td>
#                         <td id="T_2e08d_row0_col1" class="data row0 col1" >0.900000</td>
#                         <td id="T_2e08d_row0_col2" class="data row0 col2" >0.750000</td>
#                         <td id="T_2e08d_row0_col3" class="data row0 col3" >0.900000</td>
#                         <td id="T_2e08d_row0_col4" class="data row0 col4" >20.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_2e08d_level0_row1" class="row_heading level0 row1" >29414811_2_4773219892816395776</th>
#                         <td id="T_2e08d_row1_col0" class="data row1 col0" >0.136364</td>
#                         <td id="T_2e08d_row1_col1" class="data row1 col1" >0.500000</td>
#                         <td id="T_2e08d_row1_col2" class="data row1 col2" >0.045455</td>
#                         <td id="T_2e08d_row1_col3" class="data row1 col3" >0.363636</td>
#                         <td id="T_2e08d_row1_col4" class="data row1 col4" >22.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_2e08d_level0_row2" class="row_heading level0 row2" >84575189_0_6365692015941409487</th>
#                         <td id="T_2e08d_row2_col0" class="data row2 col0" >0.110000</td>
#                         <td id="T_2e08d_row2_col1" class="data row2 col1" >0.230000</td>
#                         <td id="T_2e08d_row2_col2" class="data row2 col2" >0.150000</td>
#                         <td id="T_2e08d_row2_col3" class="data row2 col3" >0.370000</td>
#                         <td id="T_2e08d_row2_col4" class="data row2 col4" >100.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_2e08d_level0_row3" class="row_heading level0 row3" >52299421_0_4473286348258170200</th>
#                         <td id="T_2e08d_row3_col0" class="data row3 col0" >0.000000</td>
#                         <td id="T_2e08d_row3_col1" class="data row3 col1" >0.000000</td>
#                         <td id="T_2e08d_row3_col2" class="data row3 col2" >0.858696</td>
#                         <td id="T_2e08d_row3_col3" class="data row3 col3" >0.880435</td>
#                         <td id="T_2e08d_row3_col4" class="data row3 col4" >92.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_2e08d_level0_row4" class="row_heading level0 row4" >28086084_0_3127660530989916727</th>
#                         <td id="T_2e08d_row4_col0" class="data row4 col0" >0.236607</td>
#                         <td id="T_2e08d_row4_col1" class="data row4 col1" >0.522321</td>
#                         <td id="T_2e08d_row4_col2" class="data row4 col2" >0.272321</td>
#                         <td id="T_2e08d_row4_col3" class="data row4 col3" >0.553571</td>
#                         <td id="T_2e08d_row4_col4" class="data row4 col4" >224.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_2e08d_level0_row5" class="row_heading level0 row5" >39759273_0_1427898308030295194</th>
#                         <td id="T_2e08d_row5_col0" class="data row5 col0" >0.580000</td>
#                         <td id="T_2e08d_row5_col1" class="data row5 col1" >0.930000</td>
#                         <td id="T_2e08d_row5_col2" class="data row5 col2" >0.650000</td>
#                         <td id="T_2e08d_row5_col3" class="data row5 col3" >0.960000</td>
#                         <td id="T_2e08d_row5_col4" class="data row5 col4" >100.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_2e08d_level0_row6" class="row_heading level0 row6" >45073662_0_3179937335063201739</th>
#                         <td id="T_2e08d_row6_col0" class="data row6 col0" >0.407407</td>
#                         <td id="T_2e08d_row6_col1" class="data row6 col1" >0.888889</td>
#                         <td id="T_2e08d_row6_col2" class="data row6 col2" >0.444444</td>
#                         <td id="T_2e08d_row6_col3" class="data row6 col3" >0.888889</td>
#                         <td id="T_2e08d_row6_col4" class="data row6 col4" >27.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_2e08d_level0_row7" class="row_heading level0 row7" >14067031_0_559833072073397908</th>
#                         <td id="T_2e08d_row7_col0" class="data row7 col0" >0.886792</td>
#                         <td id="T_2e08d_row7_col1" class="data row7 col1" >0.943396</td>
#                         <td id="T_2e08d_row7_col2" class="data row7 col2" >0.943396</td>
#                         <td id="T_2e08d_row7_col3" class="data row7 col3" >0.943396</td>
#                         <td id="T_2e08d_row7_col4" class="data row7 col4" >53.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_2e08d_level0_row8" class="row_heading level0 row8" >50270082_0_444360818941411589</th>
#                         <td id="T_2e08d_row8_col0" class="data row8 col0" >0.547619</td>
#                         <td id="T_2e08d_row8_col1" class="data row8 col1" >0.922619</td>
#                         <td id="T_2e08d_row8_col2" class="data row8 col2" >0.529762</td>
#                         <td id="T_2e08d_row8_col3" class="data row8 col3" >0.916667</td>
#                         <td id="T_2e08d_row8_col4" class="data row8 col4" >168.000000</td>
#             </tr>
#     </tbody></table>
