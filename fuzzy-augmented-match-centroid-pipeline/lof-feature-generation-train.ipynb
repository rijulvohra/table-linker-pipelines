# %%
import pandas as pd
import numpy as np
import os

# pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
# pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %%
HOME_DIR = '/Users/summ7t/dev/novartis/table-linker/t2dv2-candidates-april-28/train'

# %% [markdown]
# ### Generate lof-graph-embedding-score for any table
#
# Required datasets
# - candidate file
# - candidate feature file
# - graph_embedding_complex.tsv (generated and stored during candidate generation)
#
# Script used `lof-script.sh`
#
# ```
# filename=$1
# tsv_postfix=_graph_embedding_complex
#
# tl smallest-qnode-number train-candidates/candidates-$filename.csv \
# / align-page-rank \
# / string-similarity -i --method symmetric_monge_elkan:tokenizer=word -o monge_elkan \
# / string-similarity -i --method jaccard:tokenizer=word -c kg_descriptions context -o des_cont_jaccard \
# / normalize-scores -c des_cont_jaccard \
# / vote-by-classifier --prob-threshold 0.995 --model weighted_lr.pkl \
# > model-voted/$filename.csv
#
# tl score-using-embedding model-voted/$filename.csv \
# --column-vector-strategy centroid-of-lof \
# --lof-strategy ems-mv \
# -o graph-embedding-score \
# --embedding-file train-graph-embeddings/$filename$tsv_postfix.tsv \
# --embedding-url http://ckg07:9200/wikidatadwd-augmented/ \
# > lof-score/$filename.csv
# ```
#
# cmd: `bash {HOME_DIR}/lof-script.sh {fid}`
#
# output: lof-score/$filename.csv contains `is_lof` and `graph-embedding-score` (centroid-of-lof)

# %%
# !mkdir -p $HOME_DIR/model-voted
# !mkdir -p $HOME_DIR/lof-score
# !mkdir -p $HOME_DIR/merged-lof-score
# !mkdir -p $HOME_DIR/final-features

# %%
# list all files in candidates dir
file_names = []
file_ids = []

for (dirpath, dirnames, filenames) in os.walk(f'{HOME_DIR}/train-candidates/'):
    for fn in filenames:
        if "csv" not in fn:
            continue
        abs_fn = dirpath + fn
        assert os.path.isfile(abs_fn)
        if os.path.getsize(abs_fn) == 0:
            continue
        file_names.append(abs_fn)
        file_ids.append(fn.split('.csv')[0].split('candidates-')[1])
len(file_names), file_ids[:3]
# Out:
# (44,
#  ['69537082_0_7789694313271016902',
#   '60319454_0_3938426910282115527',
#   '16767252_0_2409448375013995751'])

# %%
# Make sure VPN is on
for idx, fid in enumerate(file_ids):
    print(f"Generating score for {idx}th file: {fid}...")
    os.system(f'bash {HOME_DIR}/lof-script.sh {fid}')
    assert os.path.isfile(f'{HOME_DIR}/model-voted/{fid}.csv'), f"Something wrong with model-voted result: {idx}th file: {fid}"
    assert os.path.isfile(f'{HOME_DIR}/lof-score/{fid}.csv'), f"Something wrong with lof-score result: {idx}th file: {fid}"
# Out:
# Generating score for 0th file: 69537082_0_7789694313271016902...
# Generating score for 1th file: 60319454_0_3938426910282115527...
# Generating score for 2th file: 16767252_0_2409448375013995751...
# Generating score for 3th file: 84548468_0_5955155464119382182...
# Generating score for 4th file: 80588006_0_6965325215443683359...
# Generating score for 5th file: 39650055_5_7135804139753401681...
# Generating score for 6th file: 8468806_0_4382447409703007384...
# Generating score for 7th file: 1438042989043_35_20150728002309-00287-ip-10-236-191-2_875026214_2...
# Generating score for 8th file: 25404227_0_2240631045609013057...
# Generating score for 9th file: 63450419_0_8012592961815711786...
# Generating score for 10th file: 53822652_0_5767892317858575530...
# Generating score for 11th file: 22864497_0_8632623712684511496...
# Generating score for 12th file: 37856682_0_6818907050314633217...
# Generating score for 13th file: 26310680_0_5150772059999313798...
# Generating score for 14th file: 29414811_12_251152470253168163...
# Generating score for 15th file: 1438042986423_95_20150728002306-00125-ip-10-236-191-2_88435628_5...
# Generating score for 16th file: 39107734_2_2329160387535788734...
# Generating score for 17th file: 40534006_0_4617468856744635526...
# Generating score for 18th file: 90196673_0_5458330029110291950...
# Generating score for 19th file: 24036779_0_5608105867560183058...
# Generating score for 20th file: 41480166_0_6681239260286218499...
# Generating score for 21th file: 1438042989018_40_20150728002309-00067-ip-10-236-191-2_57714692_2...
# Generating score for 22th file: 77694908_0_6083291340991074532...
# Generating score for 23th file: 20135078_0_7570343137119682530...
# Generating score for 24th file: 35188621_0_6058553107571275232...
# Generating score for 25th file: 54719588_0_8417197176086756912...
# Generating score for 26th file: 21245481_0_8730460088443117515...
# Generating score for 27th file: 71840765_0_6664391841933033844...
# Generating score for 28th file: 58891288_0_1117541047012405958...
# Generating score for 29th file: 39173938_0_7916056990138658530...
# Generating score for 30th file: 10579449_0_1681126353774891032...
# Generating score for 31th file: 33401079_0_9127583903019856402...
# Generating score for 32th file: 21362676_0_6854186738074119688...
# Generating score for 33th file: 38428277_0_1311643810102462607...
# Generating score for 34th file: 9834884_0_3871985887467090123...
# Generating score for 35th file: 91959037_0_7907661684242014480...
# Generating score for 36th file: 46671561_0_6122315295162029872...
# Generating score for 37th file: 50245608_0_871275842592178099...
# Generating score for 38th file: 53989675_0_8697482470743954630...
# Generating score for 39th file: 88523363_0_8180214313099580515...
# Generating score for 40th file: 29414811_13_8724394428539174350...
# Generating score for 41th file: 9567241_0_5666388268510912770...
# Generating score for 42th file: 99070098_0_2074872741302696997...
# Generating score for 43th file: 43237185_1_3636357855502246981...

# %%
# check model-voted and lof-score files
fid = '38428277_0_1311643810102462607'
model_voted_df = pd.read_csv(f'{HOME_DIR}/model-voted/{fid}.csv')
model_voted_df[model_voted_df['vote_by_classifier'] > 0]
# Out:
#        column  row                  label                    context  \
# 3           1    0                      M     111|1931|Fritz Lang|75
# 71          1    0                      M     111|1931|Fritz Lang|75
# 98          1    0                      M     111|1931|Fritz Lang|75
# 431         1    3  The Magnificent Seven  346|1960|John Sturges|318
# 441         1    3  The Magnificent Seven  346|1960|John Sturges|318
# ...       ...  ...                    ...                        ...
# 14075       1  110  The Rules of the Game    192|1939|Jean Renoir|70
# 14081       1  111           Run Lola Run    191|1998|Tom Tykwer|494
# 14082       1  111           Run Lola Run    191|1998|Tom Tykwer|494
# 14186       1  112               Rushmore  238|1998|Wes Anderson|286
# 14209       1  112               Rushmore  238|1998|Wes Anderson|286
#
#                  label_clean     kg_id              kg_labels  \
# 3                          M   Q127021                      M
# 71                         M     Q9933                      M
# 98                         M   Q127021                      M
# 431    The Magnificent Seven    Q19069  The Magnificent Seven
# 441    The Magnificent Seven    Q19069  The Magnificent Seven
# ...                      ...       ...                    ...
# 14075  The Rules of the Game   Q748599  The Rules of the Game
# 14081           Run Lola Run   Q468697           Run Lola Run
# 14082           Run Lola Run   Q468697           Run Lola Run
# 14186               Rushmore  Q1347393               Rushmore
# 14209               Rushmore  Q1347393               Rushmore
#
#                                               kg_aliases           method  \
# 3                                                    NaN      exact-match
# 71                                             Mike|m|em  fuzzy-augmented
# 98                                                   NaN  fuzzy-augmented
# 431                                    Magnificent Seven      exact-match
# 441                                    Magnificent Seven  fuzzy-augmented
# ...                                                  ...              ...
# 14075  La Regle du jeu|La Règle du jeu|Rules of the Game  fuzzy-augmented
# 14081                                                NaN      exact-match
# 14082                                                NaN  fuzzy-augmented
# 14186                                                NaN      exact-match
# 14209                                                NaN  fuzzy-augmented
#
#                                            kg_descriptions      pagerank  \
# 3        1931 German drama-thriller directed by Fritz Lang  4.462731e-09
# 71                            letter in the Latin alphabet  1.525629e-06
# 98       1931 German drama-thriller directed by Fritz Lang  4.462731e-09
# 431    1960 American western film directed by John Sturges  4.667529e-09
# 441    1960 American western film directed by John Sturges  4.667529e-09
# ...                                                    ...           ...
# 14075             1939 French film directed by Jean Renoir  3.914503e-09
# 14081                              1998 film by Tom Tykwer  4.821743e-09
# 14082                              1998 film by Tom Tykwer  4.821743e-09
# 14186                            1998 film by Wes Anderson  4.691608e-09
# 14209                            1998 film by Wes Anderson  4.691608e-09
#
#        retrieval_score  smallest_qnode_number  aligned_pagerank  monge_elkan  \
# 3            15.978438                      0      4.462731e-09          1.0
# 71            8.985167                      1      0.000000e+00          1.0
# 98            8.823359                      0      0.000000e+00          1.0
# 431          19.657589                      1      4.667529e-09          1.0
# 441          25.419687                      1      0.000000e+00          1.0
# ...                ...                    ...               ...          ...
# 14075        22.951918                      0      0.000000e+00          1.0
# 14081        21.693314                      1      4.821743e-09          1.0
# 14082        38.246160                      1      0.000000e+00          1.0
# 14186        19.499273                      0      4.691608e-09          1.0
# 14209        18.232906                      0      0.000000e+00          1.0
#
#        des_cont_jaccard  des_cont_jaccard_normalized  vote_by_classifier
# 3              0.285714                     0.571429                   1
# 71             0.000000                     0.000000                   1
# 98             0.285714                     0.571429                   1
# 431            0.250000                     0.500000                   1
# 441            0.250000                     0.500000                   1
# ...                 ...                          ...                 ...
# 14075          0.285714                     0.571429                   1
# 14081          0.400000                     0.800000                   1
# 14082          0.400000                     0.800000                   1
# 14186          0.400000                     0.800000                   1
# 14209          0.400000                     0.800000                   1
#
# [186 rows x 18 columns]

# %%
fid = '38428277_0_1311643810102462607'
score_df = pd.read_csv(f'{HOME_DIR}/lof-score/{fid}.csv')
score_df.sort_values(by=['graph-embedding-score'], ascending=False).head(10)
# Out:
#        column  row                             label  \
# 10179       1    7  The Man Who Shot Liberty Valance
# 10183       1    7  The Man Who Shot Liberty Valance
# 10080       1   69                        The Player
# 10027       1   69                        The Player
# 7641        1   52            The Outlaw Josey Wales
# 7642        1   52            The Outlaw Josey Wales
# 11497       1    8          The Manchurian Candidate
# 1688        1  109              The Royal Tenenbaums
# 1687        1  109              The Royal Tenenbaums
# 12580       1   88                       Rear Window
#
#                               context                       label_clean  \
# 10179          305|1962|John Ford|288  The Man Who Shot Liberty Valance
# 10183          305|1962|John Ford|288  The Man Who Shot Liberty Valance
# 10080      289|1992|Robert Altman|492                        The Player
# 10027      289|1992|Robert Altman|492                        The Player
# 7641      448|1976|Clint Eastwood|645            The Outlaw Josey Wales
# 7642      448|1976|Clint Eastwood|645            The Outlaw Josey Wales
# 11497  92|1962|John Frankenheimer|124          The Manchurian Candidate
# 1688        266|2001|Wes Anderson|516              The Royal Tenenbaums
# 1687        266|2001|Wes Anderson|516              The Royal Tenenbaums
# 12580     21|1954|Alfred Hitchcock|34                       Rear Window
#
#           kg_id                         kg_labels  \
# 10179   Q555687  The Man Who Shot Liberty Valance
# 10183   Q555687  The Man Who Shot Liberty Valance
# 10080  Q1551573                        The Player
# 10027  Q1551573                        The Player
# 7641    Q477630            The Outlaw Josey Wales
# 7642    Q477630            The Outlaw Josey Wales
# 11497   Q500672                     The Candidate
# 1688    Q935105              The Royal Tenenbaums
# 1687    Q935105              The Royal Tenenbaums
# 12580    Q34414                       Rear Window
#
#                          kg_aliases           method  \
# 10179  Man Who Shot Liberty Valance      exact-match
# 10183  Man Who Shot Liberty Valance  fuzzy-augmented
# 10080                        Player  fuzzy-augmented
# 10027                        Player      exact-match
# 7641             Outlaw Josey Wales      exact-match
# 7642             Outlaw Josey Wales  fuzzy-augmented
# 11497                     Candidate  fuzzy-augmented
# 1688               Royal Tenenbaums  fuzzy-augmented
# 1687               Royal Tenenbaums      exact-match
# 12580                           NaN      exact-match
#
#                                                 kg_descriptions      pagerank  \
# 10179                                    1962 film by John Ford  4.198485e-09
# 10183                                    1962 film by John Ford  4.198485e-09
# 10080                                1992 film by Robert Altman  4.266846e-09
# 10027                                1992 film by Robert Altman  4.266846e-09
# 7641                                1976 film by Clint Eastwood  4.088294e-09
# 7642                                1976 film by Clint Eastwood  4.088294e-09
# 11497                      American political comedy-drama film  3.539613e-09
# 1688                                  2001 film by Wes Anderson  3.855798e-09
# 1687                                  2001 film by Wes Anderson  3.855798e-09
# 12580  1954 American suspense film directed by Alfred Hitchcock  4.041058e-09
#
#        retrieval_score  smallest_qnode_number  aligned_pagerank  monge_elkan  \
# 10179        20.621593                      0      4.198485e-09      1.00000
# 10183        43.213043                      0      0.000000e+00      1.00000
# 10080        17.465298                      0      0.000000e+00      1.00000
# 10027        18.660294                      0      4.266846e-09      1.00000
# 7641         21.693314                      0      4.088294e-09      1.00000
# 7642         38.130527                      0      0.000000e+00      1.00000
# 11497        28.223623                      0      0.000000e+00      0.93642
# 1688         34.257706                      0      0.000000e+00      1.00000
# 1687         21.047188                      0      3.855798e-09      1.00000
# 12580        20.621593                      0      4.041058e-09      1.00000
#
#        des_cont_jaccard  des_cont_jaccard_normalized  vote_by_classifier  \
# 10179              0.40                          0.8                   1
# 10183              0.40                          0.8                   1
# 10080              0.40                          0.8                   1
# 10027              0.40                          0.8                   1
# 7641               0.40                          0.8                   1
# 7642               0.40                          0.8                   1
# 11497              0.00                          0.0                   0
# 1688               0.40                          0.8                   1
# 1687               0.40                          0.8                   1
# 12580              0.25                          0.5                   0
#
#        singleton  is_lof  graph-embedding-score
# 10179          0       1               0.898658
# 10183          0       1               0.898658
# 10080          0       1               0.884048
# 10027          0       1               0.884048
# 7641           1       1               0.883297
# 7642           0       1               0.883297
# 11497          0      -1               0.878668
# 1688           0       1               0.875843
# 1687           0       1               0.875843
# 12580          0      -1               0.875510

# %%
# merge lof candidate (graph-embedding-score) with candidate feature file
for idx, fid in enumerate(file_ids):
    print(f"Merging embedding score for {idx}th file: {fid}...")
    features_df = pd.read_csv(f'{HOME_DIR}/train-features/{fid}.csv')
    lof_score_df = pd.read_csv(f'{HOME_DIR}/lof-score/{fid}.csv')
    lof_score_df.rename(columns = {'graph-embedding-score':'lof-graph-embedding-score'}, inplace = True)
    trimmed_lof_score_df = lof_score_df.loc[:, ['column', 'row', 'kg_id', 'method', 'lof-graph-embedding-score', 'is_lof']]
    
    # merge two df on row, column, kg_id
    final_df = pd.merge(features_df, trimmed_lof_score_df, left_on=['column', 'row', 'kg_id', 'method'], right_on = ['column', 'row', 'kg_id', 'method'])
    final_df.drop_duplicates(inplace=True)
    assert len(final_df) == len(features_df), f"{len(features_df)}, {len(final_df)}"
    
    final_df.to_csv(f"{HOME_DIR}/merged-lof-score/{fid}.csv", index=False)
    assert os.path.isfile(f'{HOME_DIR}/merged-lof-score/{fid}.csv'), f"Something wrong with merged score result: {idx}th file: {fid}"
# Out:
# Merging embedding score for 0th file: 69537082_0_7789694313271016902...
# Merging embedding score for 1th file: 60319454_0_3938426910282115527...
# Merging embedding score for 2th file: 16767252_0_2409448375013995751...
# Merging embedding score for 3th file: 84548468_0_5955155464119382182...
# Merging embedding score for 4th file: 80588006_0_6965325215443683359...
# Merging embedding score for 5th file: 39650055_5_7135804139753401681...
# Merging embedding score for 6th file: 8468806_0_4382447409703007384...
# Merging embedding score for 7th file: 1438042989043_35_20150728002309-00287-ip-10-236-191-2_875026214_2...
# Merging embedding score for 8th file: 25404227_0_2240631045609013057...
# Merging embedding score for 9th file: 63450419_0_8012592961815711786...
# Merging embedding score for 10th file: 53822652_0_5767892317858575530...
# Merging embedding score for 11th file: 22864497_0_8632623712684511496...
# Merging embedding score for 12th file: 37856682_0_6818907050314633217...
# Merging embedding score for 13th file: 26310680_0_5150772059999313798...
# Merging embedding score for 14th file: 29414811_12_251152470253168163...
# Merging embedding score for 15th file: 1438042986423_95_20150728002306-00125-ip-10-236-191-2_88435628_5...
# Merging embedding score for 16th file: 39107734_2_2329160387535788734...
# Merging embedding score for 17th file: 40534006_0_4617468856744635526...
# Merging embedding score for 18th file: 90196673_0_5458330029110291950...
# Merging embedding score for 19th file: 24036779_0_5608105867560183058...
# Merging embedding score for 20th file: 41480166_0_6681239260286218499...
# Merging embedding score for 21th file: 1438042989018_40_20150728002309-00067-ip-10-236-191-2_57714692_2...
# Merging embedding score for 22th file: 77694908_0_6083291340991074532...
# Merging embedding score for 23th file: 20135078_0_7570343137119682530...
# Merging embedding score for 24th file: 35188621_0_6058553107571275232...
# Merging embedding score for 25th file: 54719588_0_8417197176086756912...
# Merging embedding score for 26th file: 21245481_0_8730460088443117515...
# Merging embedding score for 27th file: 71840765_0_6664391841933033844...
# Merging embedding score for 28th file: 58891288_0_1117541047012405958...
# Merging embedding score for 29th file: 39173938_0_7916056990138658530...
# Merging embedding score for 30th file: 10579449_0_1681126353774891032...
# Merging embedding score for 31th file: 33401079_0_9127583903019856402...
# Merging embedding score for 32th file: 21362676_0_6854186738074119688...
# Merging embedding score for 33th file: 38428277_0_1311643810102462607...
# Merging embedding score for 34th file: 9834884_0_3871985887467090123...
# Merging embedding score for 35th file: 91959037_0_7907661684242014480...
# Merging embedding score for 36th file: 46671561_0_6122315295162029872...
# Merging embedding score for 37th file: 50245608_0_871275842592178099...
# Merging embedding score for 38th file: 53989675_0_8697482470743954630...
# Merging embedding score for 39th file: 88523363_0_8180214313099580515...
# Merging embedding score for 40th file: 29414811_13_8724394428539174350...
# Merging embedding score for 41th file: 9567241_0_5666388268510912770...
# Merging embedding score for 42th file: 99070098_0_2074872741302696997...
# Merging embedding score for 43th file: 43237185_1_3636357855502246981...

# %%
# check merged train feature files
fid = '50245608_0_871275842592178099'
merged_score_df = pd.read_csv(f'{HOME_DIR}/merged-lof-score/{fid}.csv')
# merged_score_df.sort_values(by=['lof-graph-embedding-score'], ascending=False).head(10)
merged_score_df[merged_score_df['is_lof'] == 1]
# Out:
#        column  row               label  \
# 106         0    1        12 Angry Men
# 204         0    1        12 Angry Men
# 326         0   10  American History X
# 460         0  100             Hackers
# 465         0  101       Happy Gilmore
# ...       ...  ...                 ...
# 32409       0   94          Goodfellas
# 32414       0   95         Gran Torino
# 32520       0   95         Gran Torino
# 32812       0   98   Great Gatsby, The
# 33014       0   99       Groundhog Day
#
#                                                          context  \
# 106            1957|DVD|Sidney Lumet|Reginald Rose|96|Widescreen
# 204            1957|DVD|Sidney Lumet|Reginald Rose|96|Widescreen
# 326              1998|DVD|Tony Kaye|David McKenna|119|Widescreen
# 460            1995|DVD|Iain Softley|Rafael Moreu|107|Widescreen
# 465              1996|DVD|Dennis Dugan|Tim Herlihy|92|Widescreen
# ...                                                          ...
# 32409   1990|DVD|Martin Scorsese|Nicholas Pileggi|145|Widescreen
# 32414     2008|Blu-Ray|Clint Eastwood|Nick Schenk|116|Widescreen
# 32520     2008|Blu-Ray|Clint Eastwood|Nick Schenk|116|Widescreen
# 32812  1974|DVD|Jack Clayton|Francis Ford Coppola|144|Widescreen
# 33014           1993|DVD|Harold Ramis|Danny Rubin|101|Widescreen
#
#               label_clean     kg_id           kg_labels  \
# 106          12 Angry Men     Q2345        12 Angry Men
# 204          12 Angry Men     Q2345        12 Angry Men
# 326    American History X   Q208572  American History X
# 460               Hackers    Q13908             Hackers
# 465         Happy Gilmore  Q1313063       Happy Gilmore
# ...                   ...       ...                 ...
# 32409          Goodfellas    Q42047          Goodfellas
# 32414         Gran Torino   Q126699         Gran Torino
# 32520         Gran Torino   Q126699         Gran Torino
# 32812   Great Gatsby, The  Q1198799    The Great Gatsby
# 33014       Groundhog Day   Q488655       Groundhog Day
#
#                             kg_aliases           method  \
# 106                   Twelve Angry Men  fuzzy-augmented
# 204                   Twelve Angry Men      exact-match
# 326                                NaN      exact-match
# 460                                NaN      exact-match
# 465                                NaN  fuzzy-augmented
# ...                                ...              ...
# 32409  Morrie\s Wig Shop|Morrie\s Wigs      exact-match
# 32414                              NaN  fuzzy-augmented
# 32520                              NaN      exact-match
# 32812                     Great Gatsby  fuzzy-augmented
# 33014              \\ Groundhog Day \\      exact-match
#
#                                    kg_descriptions      pagerank  \
# 106       1957 American drama film by Sidney Lumet  1.424518e-05
# 204       1957 American drama film by Sidney Lumet  1.424518e-05
# 326          1998 drama film directed by Tony Kaye  5.971302e-09
# 460    1995 American thriller film by Iain Softley  3.539613e-09
# 465                      1996 film by Dennis Dugan  5.264195e-09
# ...                                            ...           ...
# 32409                 1990 film by Martin Scorsese  3.841212e-09
# 32414                  2008 film by Clint Eastwood  3.840480e-09
# 32520                  2008 film by Clint Eastwood  3.840480e-09
# 32812                    1974 film by Jack Clayton  3.925254e-09
# 33014    1993 comedy film directed by Harold Ramis  5.516946e-09
#
#        retrieval_score  GT_kg_id         GT_kg_label  evaluation_label  \
# 106          27.113117     Q2345        12 Angry Men                 1
# 204          20.049892     Q2345        12 Angry Men                 1
# 326          21.693314   Q208572  American History X                 1
# 460          20.049892    Q13908             Hackers                 1
# 465          23.724293  Q1313063       Happy Gilmore                 1
# ...                ...       ...                 ...               ...
# 32409        19.838593    Q42047          Goodfellas                 1
# 32414        29.181086   Q126699         Gran Torino                 1
# 32520        21.693314   Q126699         Gran Torino                 1
# 32812        28.070555  Q1198799    The Great Gatsby                 1
# 33014        20.049892   Q488655       Groundhog Day                 1
#
#        monge_elkan  des_cont_jaccard  jaro_winkler  graph-embedding-score  \
# 106       1.000000          0.285714      1.000000               0.776624
# 204       1.000000          0.285714      1.000000               0.776624
# 326       1.000000          0.285714      1.000000               0.794793
# 460       1.000000          0.285714      1.000000               0.825205
# 465       1.000000          0.400000      1.000000               0.788162
# ...            ...               ...           ...                    ...
# 32409     1.000000          0.400000      1.000000               0.806880
# 32414     1.000000          0.400000      1.000000               0.805404
# 32520     1.000000          0.400000      1.000000               0.805404
# 32812     0.990476          0.400000      0.732843               0.810695
# 33014     1.000000          0.285714      1.000000               0.815621
#
#        singleton  reciprocal_rank  num_char  num_tokens  \
# 106            0         0.200000        12           3
# 204            0         0.166667        12           3
# 326            1         0.500000        18           3
# 460            0         0.500000         7           1
# 465            0         1.000000        13           2
# ...          ...              ...       ...         ...
# 32409          0         0.500000        10           1
# 32414          0         1.000000        11           2
# 32520          1         0.500000        11           2
# 32812          0         1.000000        16           3
# 33014          0         0.500000        13           2
#
#        class_count_tf_idf_score  property_count_tf_idf_score  \
# 106                    0.170207                     0.497526
# 204                    0.170207                     0.497526
# 326                    0.170207                     0.408187
# 460                    0.170207                     0.328429
# 465                    0.170207                     0.330090
# ...                         ...                          ...
# 32409                  0.170207                     0.450226
# 32414                  0.170207                     0.384093
# 32520                  0.170207                     0.384093
# 32812                  0.170207                     0.365816
# 33014                  0.170207                     0.447306
#
#        lof-graph-embedding-score  is_lof
# 106                     0.816226       1
# 204                     0.816226       1
# 326                     0.819788       1
# 460                     0.832763       1
# 465                     0.779795       1
# ...                          ...     ...
# 32409                   0.844393       1
# 32414                   0.804078       1
# 32520                   0.804078       1
# 32812                   0.837175       1
# 33014                   0.820809       1
#
# [158 rows x 27 columns]

# %%
# Generate lof-reciprocal-rank
for idx, fid in enumerate(file_ids):
    print(f"generating final feature for {idx}th file: {fid}")
    class_count_f = f'{HOME_DIR}/train-class-count/{fid}_class_count.tsv'
    property_count_f = f'{HOME_DIR}/train-prop-count/{fid}_prop_count.tsv'
    merged_lof_f = f'{HOME_DIR}/merged-lof-score/{fid}.csv'
    final_features_f = f'{HOME_DIR}/final-features/{fid}.csv'
    script = f"""
    tl generate-reciprocal-rank {merged_lof_f} \
    -c lof-graph-embedding-score \
    -o lof-reciprocal-rank \
    / compute-tf-idf \
    --feature-file {class_count_f} \
    --feature-name class_count \
    --singleton-column is_lof \
    -o lof_class_count_tf_idf_score \
    / compute-tf-idf \
    --feature-file {property_count_f} \
    --feature-name property_count \
    --singleton-column is_lof \
    -o lof_property_count_tf_idf_score \
    > {final_features_f}
    """
    os.system(script)
    assert os.path.isfile(final_features_f), f"Something wrong with final feature result: {idx}th file: {fid}"
# Out:
# generating final feature for 0th file: 69537082_0_7789694313271016902
# generating final feature for 1th file: 60319454_0_3938426910282115527
# generating final feature for 2th file: 16767252_0_2409448375013995751
# generating final feature for 3th file: 84548468_0_5955155464119382182
# generating final feature for 4th file: 80588006_0_6965325215443683359
# generating final feature for 5th file: 39650055_5_7135804139753401681
# generating final feature for 6th file: 8468806_0_4382447409703007384
# generating final feature for 7th file: 1438042989043_35_20150728002309-00287-ip-10-236-191-2_875026214_2
# generating final feature for 8th file: 25404227_0_2240631045609013057
# generating final feature for 9th file: 63450419_0_8012592961815711786
# generating final feature for 10th file: 53822652_0_5767892317858575530
# generating final feature for 11th file: 22864497_0_8632623712684511496
# generating final feature for 12th file: 37856682_0_6818907050314633217
# generating final feature for 13th file: 26310680_0_5150772059999313798
# generating final feature for 14th file: 29414811_12_251152470253168163
# generating final feature for 15th file: 1438042986423_95_20150728002306-00125-ip-10-236-191-2_88435628_5
# generating final feature for 16th file: 39107734_2_2329160387535788734
# generating final feature for 17th file: 40534006_0_4617468856744635526
# generating final feature for 18th file: 90196673_0_5458330029110291950
# generating final feature for 19th file: 24036779_0_5608105867560183058
# generating final feature for 20th file: 41480166_0_6681239260286218499
# generating final feature for 21th file: 1438042989018_40_20150728002309-00067-ip-10-236-191-2_57714692_2
# generating final feature for 22th file: 77694908_0_6083291340991074532
# generating final feature for 23th file: 20135078_0_7570343137119682530
# generating final feature for 24th file: 35188621_0_6058553107571275232
# generating final feature for 25th file: 54719588_0_8417197176086756912
# generating final feature for 26th file: 21245481_0_8730460088443117515
# generating final feature for 27th file: 71840765_0_6664391841933033844
# generating final feature for 28th file: 58891288_0_1117541047012405958
# generating final feature for 29th file: 39173938_0_7916056990138658530
# generating final feature for 30th file: 10579449_0_1681126353774891032
# generating final feature for 31th file: 33401079_0_9127583903019856402
# generating final feature for 32th file: 21362676_0_6854186738074119688
# generating final feature for 33th file: 38428277_0_1311643810102462607
# generating final feature for 34th file: 9834884_0_3871985887467090123
# generating final feature for 35th file: 91959037_0_7907661684242014480
# generating final feature for 36th file: 46671561_0_6122315295162029872
# generating final feature for 37th file: 50245608_0_871275842592178099
# generating final feature for 38th file: 53989675_0_8697482470743954630
# generating final feature for 39th file: 88523363_0_8180214313099580515
# generating final feature for 40th file: 29414811_13_8724394428539174350
# generating final feature for 41th file: 9567241_0_5666388268510912770
# generating final feature for 42th file: 99070098_0_2074872741302696997
# generating final feature for 43th file: 43237185_1_3636357855502246981

# %%
#     / compute-tf-idf \
#     --feature-file {class_count_f} \
#     --feature-name class_count \
#     --singleton-column singleton \
#     -o cos_class_count_tf_idf_score \
#     / compute-tf-idf \
#     --feature-file {property_count_f} \
#     --feature-name property_count \
#     --singleton-column singleton \
#     -o cos_property_count_tf_idf_score \

# %%
# check final feature files
fid = '9567241_0_5666388268510912770'
final_feature_df = pd.read_csv(f'{HOME_DIR}/final-features/{fid}.csv')
final_feature_df[final_feature_df['evaluation_label'] == 1].loc[:, [
    'property_count_tf_idf_score', 'lof_property_count_tf_idf_score',
    'class_count_tf_idf_score', 'lof_class_count_tf_idf_score'
]]
# Out:
#       property_count_tf_idf_score  lof_property_count_tf_idf_score  \
# 0                        0.103461                         0.324091
# 100                      0.103461                         0.324091
# 101                      0.136712                         0.428248
# 201                      0.136712                         0.428248
# 202                      0.365876                         0.711858
# 362                      0.867718                         0.807535
# 458                      0.867718                         0.807535
# 459                      0.145132                         0.454624
# 559                      0.145132                         0.454624
# 704                      0.082228                         0.189750
# 723                      0.305087                         0.754783
# 828                      0.305087                         0.754783
# 841                      0.185492                         0.480168
# 1020                     0.099231                         0.297045
# 1671                     0.209310                         0.655663
# 1771                     0.209310                         0.655663
# 1820                     0.050502                         0.158196
# 1919                     0.056092                         0.157806
# 1940                     0.056092                         0.157806
# 1941                     0.091921                         0.287942
# 2041                     0.091921                         0.287942
# 2042                     0.106387                         0.333258
# 2063                     0.106387                         0.333258
#
#       class_count_tf_idf_score  lof_class_count_tf_idf_score
# 0                     0.215613                      0.560593
# 100                   0.215613                      0.560593
# 101                   0.235488                      0.612268
# 201                   0.235488                      0.612268
# 202                   0.235488                      0.612268
# 362                   0.852363                      0.698913
# 458                   0.852363                      0.698913
# 459                   0.341726                      0.888485
# 559                   0.341726                      0.888485
# 704                   0.147975                      0.296759
# 723                   0.235488                      0.612268
# 828                   0.235488                      0.612268
# 841                   0.235488                      0.612268
# 1020                  0.215613                      0.560593
# 1671                  0.215613                      0.560593
# 1771                  0.215613                      0.560593
# 1820                  0.094390                      0.245414
# 1919                  0.708782                      0.560593
# 1940                  0.708782                      0.560593
# 1941                  0.235488                      0.612268
# 2041                  0.235488                      0.612268
# 2042                  0.215613                      0.560593
# 2063                  0.215613                      0.560593

# %%
len(final_feature_df.groupby(['column', 'row']))
# Out:
# 21

# %%
len(final_feature_df[final_feature_df['is_lof'] == 1]), \
len(final_feature_df[(final_feature_df['is_lof'] == 1) & (final_feature_df['evaluation_label'] == 1)]), \
len(final_feature_df[final_feature_df['singleton'] == 1]), \
len(final_feature_df[(final_feature_df['singleton'] == 1) & (final_feature_df['evaluation_label'] == 1)])
# Out:
# (7, 6, 11, 8)

# %%
# min-max scaling on tfidf score
cos_class_tfidf_max = final_feature_df['class_count_tf_idf_score'].max()
cos_class_tfidf_min = final_feature_df['class_count_tf_idf_score'].min()
cos_property_tfidf_max = final_feature_df['property_count_tf_idf_score'].max()
cos_property_tfidf_min = final_feature_df['property_count_tf_idf_score'].min()
lof_class_tfidf_max = final_feature_df['lof_class_count_tf_idf_score'].max()
lof_class_tfidf_min = final_feature_df['lof_class_count_tf_idf_score'].min()
lof_property_tfidf_max = final_feature_df['lof_property_count_tf_idf_score'].max()
lof_property_tfidf_min = final_feature_df['lof_property_count_tf_idf_score'].min()
final_feature_df['class_count_tf_idf_score'] = (final_feature_df['class_count_tf_idf_score'] - cos_class_tfidf_min) / (cos_class_tfidf_max - cos_class_tfidf_min)
final_feature_df['property_count_tf_idf_score'] = (final_feature_df['property_count_tf_idf_score'] - cos_property_tfidf_min) / (cos_property_tfidf_max - cos_property_tfidf_min)
final_feature_df['lof_class_count_tf_idf_score'] = (final_feature_df['lof_class_count_tf_idf_score'] - lof_class_tfidf_min) / (lof_class_tfidf_max - lof_class_tfidf_min)
final_feature_df['lof_property_count_tf_idf_score'] = (final_feature_df['lof_property_count_tf_idf_score'] - lof_property_tfidf_min) / (lof_property_tfidf_max - lof_property_tfidf_min)
final_feature_df
# Out:
#       column  row          label   context    label_clean      kg_id  \
# 0          1    0  Dainik Jagran  1|15.400  Dainik Jagran   Q1318465
# 1          1    0  Dainik Jagran  1|15.400  Dainik Jagran  Q20984008
# 2          1    0  Dainik Jagran  1|15.400  Dainik Jagran  Q15240907
# 3          1    0  Dainik Jagran  1|15.400  Dainik Jagran  Q55614827
# 4          1    0  Dainik Jagran  1|15.400  Dainik Jagran  Q14632383
# ...      ...  ...            ...       ...            ...        ...
# 2059       1    9      Dinamalar  10|3.500      Dinamalar  Q69536690
# 2060       1    9      Dinamalar  10|3.500      Dinamalar     Q35336
# 2061       1    9      Dinamalar  10|3.500      Dinamalar  Q97448743
# 2062       1    9      Dinamalar  10|3.500      Dinamalar   Q5277834
# 2063       1    9      Dinamalar  10|3.500      Dinamalar   Q3246100
#
#                                         kg_labels  \
# 0                                   Dainik Jagran
# 1                                     Dainik Asam
# 2                                          Kutton
# 3                        Jagran Prakashan Limited
# 4                                          Jagran
# ...                                           ...
# 2059  Allahabad Bank Ssm College Dinanagar branch
# 2060                                      Djimini
# 2061                                          NaN
# 2062                                    Dina Azar
# 2063                                    Dinamalar
#
#                             kg_aliases           method  \
# 0                                  NaN  fuzzy-augmented
# 1                                  NaN  fuzzy-augmented
# 2                                  NaN  fuzzy-augmented
# 3                     Jagran Prakashan  fuzzy-augmented
# 4                                  NaN  fuzzy-augmented
# ...                                ...              ...
# 2059                               NaN  fuzzy-augmented
# 2060  Djimini Senoufo|Djimini language  fuzzy-augmented
# 2061                               NaN  fuzzy-augmented
# 2062                               NaN  fuzzy-augmented
# 2063                               NaN      exact-match
#
#                                         kg_descriptions      pagerank  \
# 0                                             newspaper  4.597725e-09
# 1                                                   NaN  3.539613e-09
# 2                     village in Azad Kashmir, Pakistan  4.099829e-09
# 3     Indian newspaper publisher and mass media company  1.493805e-08
# 4                                  village in Indonesia  7.991804e-09
# ...                                                 ...           ...
# 2059                                      Bank in India  3.539613e-09
# 2060                                           language  3.183702e-07
# 2061                                                NaN  3.539613e-09
# 2062                                     Lebanese model  3.539613e-09
# 2063                              daily Tamil newspaper  3.539613e-09
#
#       retrieval_score  GT_kg_id    GT_kg_label  evaluation_label  monge_elkan  \
# 0           39.010326  Q1318465  Dainik Jagran                 1     1.000000
# 1           20.664627  Q1318465  Dainik Jagran                -1     0.805556
# 2           20.076506  Q1318465  Dainik Jagran                -1     0.444444
# 3           20.076506  Q1318465  Dainik Jagran                -1     0.748898
# 4           18.884026  Q1318465  Dainik Jagran                -1     0.888889
# ...               ...       ...            ...               ...          ...
# 2059         8.612831  Q3246100      Dinamalar                -1     0.675110
# 2060         6.524282  Q3246100      Dinamalar                -1     0.588624
# 2061         5.136879  Q3246100      Dinamalar                -1     0.000000
# 2062        15.405266  Q3246100      Dinamalar                -1     0.780093
# 2063        21.693314  Q3246100      Dinamalar                 1     1.000000
#
#       des_cont_jaccard  jaro_winkler  graph-embedding-score  singleton  \
# 0                  0.0      1.000000               0.773640          0
# 1                  0.0      0.902098               0.681579          0
# 2                  0.0      0.414530               0.537725          0
# 3                  0.0      0.566239               0.729553          0
# 4                  0.0      0.495726               0.569860          0
# ...                ...           ...                    ...        ...
# 2059               0.0      0.429156               0.621177          0
# 2060               0.0      0.588624               0.485838          0
# 2061               0.0      0.000000               0.659981          0
# 2062               0.0      0.911111               0.273327          0
# 2063               0.0      1.000000               0.730930          1
#
#       reciprocal_rank  num_char  num_tokens  class_count_tf_idf_score  \
# 0            0.250000        13           2                  0.252959
# 1            0.041667        11           2                  0.110739
# 2            0.021277         6           1                  0.046999
# 3            0.062500        24           3                  0.161634
# 4            0.024390         6           1                  0.046999
# ...               ...       ...         ...                       ...
# 2059         0.111111        43           6                  0.043232
# 2060         0.052632         7           1                  0.013840
# 2061         0.200000         0           0                  0.209321
# 2062         0.047619         9           2                  0.016704
# 2063         0.500000         9           1                  0.252959
#
#       property_count_tf_idf_score  lof-graph-embedding-score  is_lof  \
# 0                        0.119233                   0.878575      -1
# 1                        0.037485                   0.745750      -1
# 2                        0.010682                   0.525195      -1
# 3                        0.087082                   0.760178      -1
# 4                        0.010372                   0.514971      -1
# ...                           ...                        ...     ...
# 2059                     0.010279                   0.624439      -1
# 2060                     0.004998                   0.504227      -1
# 2061                     0.000026                   0.620545      -1
# 2062                     0.003346                   0.254219      -1
# 2063                     0.122606                   0.787062       1
#
#       lof-reciprocal-rank  lof_class_count_tf_idf_score  \
# 0                1.000000                      0.630953
# 1                0.052632                      0.276216
# 2                0.021739                      0.111370
# 3                0.066667                      0.403162
# 4                0.020833                      0.111370
# ...                   ...                           ...
# 2059             0.142857                      0.101973
# 2060             0.058824                      0.007505
# 2061             0.125000                      0.164232
# 2062             0.047619                      0.041665
# 2063             0.500000                      0.630953
#
#       lof_property_count_tf_idf_score
# 0                            0.401334
# 1                            0.126171
# 2                            0.035954
# 3                            0.207393
# 4                            0.012742
# ...                               ...
# 2059                         0.012742
# 2060                         0.016824
# 2061                         0.000087
# 2062                         0.011263
# 2063                         0.412685
#
# [2064 rows x 30 columns]

# %%
final_feature_df[final_feature_df['evaluation_label'] == 1].loc[:, ['kg_id', 'method', 'class_count_tf_idf_score', 'property_count_tf_idf_score', 'lof_class_count_tf_idf_score', 'lof_property_count_tf_idf_score']]
# Out:
#          kg_id           method  class_count_tf_idf_score  \
# 0     Q1318465  fuzzy-augmented                  0.252959
# 100   Q1318465      exact-match                  0.252959
# 101   Q1872524  fuzzy-augmented                  0.276277
# 201   Q1872524      exact-match                  0.276277
# 202    Q164746  fuzzy-augmented                  0.276277
# 362      Q9684  fuzzy-augmented                  1.000000
# 458      Q9684      exact-match                  1.000000
# 459   Q2129720  fuzzy-augmented                  0.400916
# 559   Q2129720      exact-match                  0.400916
# 704   Q1023924  fuzzy-augmented                  0.173605
# 723     Q39681  fuzzy-augmented                  0.276277
# 828     Q39681      exact-match                  0.276277
# 841    Q208875  fuzzy-augmented                  0.276277
# 1020   Q483903  fuzzy-augmented                  0.252959
# 1671    Q46807  fuzzy-augmented                  0.252959
# 1771    Q46807      exact-match                  0.252959
# 1820  Q3214299  fuzzy-augmented                  0.110739
# 1919  Q6735687  fuzzy-augmented                  0.831549
# 1940  Q6735687      exact-match                  0.831549
# 1941  Q2732186  fuzzy-augmented                  0.276277
# 2041  Q2732186      exact-match                  0.276277
# 2042  Q3246100  fuzzy-augmented                  0.252959
# 2063  Q3246100      exact-match                  0.252959
#
#       property_count_tf_idf_score  lof_class_count_tf_idf_score  \
# 0                        0.119233                      0.630953
# 100                      0.119233                      0.630953
# 101                      0.157553                      0.689114
# 201                      0.157553                      0.689114
# 202                      0.421653                      0.689114
# 362                      1.000000                      0.786635
# 458                      1.000000                      0.786635
# 459                      0.167257                      1.000000
# 559                      0.167257                      1.000000
# 704                      0.094764                      0.334006
# 723                      0.351597                      0.689114
# 828                      0.351597                      0.689114
# 841                      0.213770                      0.689114
# 1020                     0.114359                      0.630953
# 1671                     0.241219                      0.630953
# 1771                     0.241219                      0.630953
# 1820                     0.058200                      0.276216
# 1919                     0.064644                      0.630953
# 1940                     0.064644                      0.630953
# 1941                     0.105934                      0.689114
# 2041                     0.105934                      0.689114
# 2042                     0.122606                      0.630953
# 2063                     0.122606                      0.630953
#
#       lof_property_count_tf_idf_score
# 0                            0.401334
# 100                          0.401334
# 101                          0.530315
# 201                          0.530315
# 202                          0.881520
# 362                          1.000000
# 458                          1.000000
# 459                          0.562977
# 559                          0.562977
# 704                          0.234974
# 723                          0.934676
# 828                          0.934676
# 841                          0.594610
# 1020                         0.367842
# 1671                         0.811931
# 1771                         0.811931
# 1820                         0.195900
# 1919                         0.195417
# 1940                         0.195417
# 1941                         0.356569
# 2041                         0.356569
# 2042                         0.412685
# 2063                         0.412685

# %%
final_feature_df[
    (final_feature_df['evaluation_label'] == 1) & (final_feature_df['property_count_tf_idf_score'] < final_feature_df['lof_property_count_tf_idf_score'])
]
# Out:
#       column  row                    label   context              label_clean  \
# 0          1    0            Dainik Jagran  1|15.400            Dainik Jagran
# 100        1    0            Dainik Jagran  1|15.400            Dainik Jagran
# 101        1    1           Dainik Bhaskar  2|14.000           Dainik Bhaskar
# 201        1    1           Dainik Bhaskar  2|14.000           Dainik Bhaskar
# 202        1   10  WALL STREET JOURNAL USA  11|3.400  WALL STREET JOURNAL USA
# 459        1   13         Gujarat Samachar  14|3.000         Gujarat Samachar
# 559        1   13         Gujarat Samachar  14|3.000         Gujarat Samachar
# 704        1   15                 IBN live  16|2.800                 IBN live
# 723        1   16                USA Today  17|2.525                USA Today
# 828        1   16                USA Today  17|2.525                USA Today
# 841        1   17                  The Sun  18|2.500                  The Sun
# 1020       1   18           Joong Ang Ilbo  19|2.250           Joong Ang Ilbo
# 1671       1    5           Times of India   6|4.800           Times of India
# 1771       1    5           Times of India   6|4.800           Times of India
# 1820       1    6                    Globo   7|4.500                    Globo
# 1919       1    7                Dailymail   8|4.500                Dailymail
# 1940       1    7                Dailymail   8|4.500                Dailymail
# 1941       1    8        Malayala Manorama   9|4.000        Malayala Manorama
# 2041       1    8        Malayala Manorama   9|4.000        Malayala Manorama
# 2042       1    9                Dinamalar  10|3.500                Dinamalar
# 2063       1    9                Dinamalar  10|3.500                Dinamalar
#
#          kg_id                kg_labels  \
# 0     Q1318465            Dainik Jagran
# 100   Q1318465            Dainik Jagran
# 101   Q1872524           Dainik Bhaskar
# 201   Q1872524           Dainik Bhaskar
# 202    Q164746  The Wall Street Journal
# 459   Q2129720         Gujarat Samachar
# 559   Q2129720         Gujarat Samachar
# 704   Q1023924               CNN-News18
# 723     Q39681                USA Today
# 828     Q39681                USA Today
# 841    Q208875                  The Sun
# 1020   Q483903       The Joong-ang Ilbo
# 1671    Q46807       The Times of India
# 1771    Q46807       The Times of India
# 1820  Q3214299                 Il Globo
# 1919  Q6735687              Mail Online
# 1940  Q6735687              Mail Online
# 1941  Q2732186        Malayala Manorama
# 2041  Q2732186        Malayala Manorama
# 2042  Q3246100                Dinamalar
# 2063  Q3246100                Dinamalar
#
#                                                                  kg_aliases  \
# 0                                                                       NaN
# 100                                                                     NaN
# 101                                                                     NaN
# 201                                                                     NaN
# 202                                     Wall Street Journal|WSJ|The Journal
# 459                                                   Lok Prakashan Limited
# 559                                                   Lok Prakashan Limited
# 704                                                       CNN-IBN|CNNNews18
# 723                                                                usatoday
# 828                                                                usatoday
# 841                  thesun.co.uk|Sun|The Sun (United Kingdom)|The Sun (UK)
# 1020                                                          JoongAng Ilbo
# 1671  India Times|indiatimes.com|Times of India|timesofindia.indiatimes.com
# 1771  India Times|indiatimes.com|Times of India|timesofindia.indiatimes.com
# 1820                                                                    NaN
# 1919      DailyMail.co.uk|Dailymail|MailOnline.co.uk|Mail Online|MailOnline
# 1940      DailyMail.co.uk|Dailymail|MailOnline.co.uk|Mail Online|MailOnline
# 1941                                                               Manorama
# 2041                                                               Manorama
# 2042                                                                    NaN
# 2063                                                                    NaN
#
#                method  \
# 0     fuzzy-augmented
# 100       exact-match
# 101   fuzzy-augmented
# 201       exact-match
# 202   fuzzy-augmented
# 459   fuzzy-augmented
# 559       exact-match
# 704   fuzzy-augmented
# 723   fuzzy-augmented
# 828       exact-match
# 841   fuzzy-augmented
# 1020  fuzzy-augmented
# 1671  fuzzy-augmented
# 1771      exact-match
# 1820  fuzzy-augmented
# 1919  fuzzy-augmented
# 1940      exact-match
# 1941  fuzzy-augmented
# 2041      exact-match
# 2042  fuzzy-augmented
# 2063      exact-match
#
#                                                                   kg_descriptions  \
# 0                                                                       newspaper
# 100                                                                     newspaper
# 101                                                               Hindi Newspaper
# 201                                                               Hindi Newspaper
# 202                                                      American daily newspaper
# 459                                    Gujarati language daily newspaper in India
# 559                                    Gujarati language daily newspaper in India
# 704                               Indian English-language news television channel
# 723                                             American national daily newspaper
# 828                                             American national daily newspaper
# 841                         tabloid newspaper from the United Kingdom and Ireland
# 1020                                                                    newspaper
# 1671                                      Indian English-language daily newspaper
# 1771                                      Indian English-language daily newspaper
# 1820                 Italian language newspaper published in Melbourne, Australia
# 1919  Website of the British newspapers the \Daily Mail\ and \The Mail on Sunday\
# 1940  Website of the British newspapers the \Daily Mail\ and \The Mail on Sunday\
# 1941  It is one of the prominent newspaper in Kerala and also a magazine company.
# 2041  It is one of the prominent newspaper in Kerala and also a magazine company.
# 2042                                                        daily Tamil newspaper
# 2063                                                        daily Tamil newspaper
#
#           pagerank  retrieval_score  GT_kg_id              GT_kg_label  \
# 0     4.597725e-09        39.010326  Q1318465            Dainik Jagran
# 100   4.597725e-09        21.693314  Q1318465            Dainik Jagran
# 101   3.539613e-09        30.801334  Q1872524           Dainik Bhaskar
# 201   3.539613e-09        21.693314  Q1872524           Dainik Bhaskar
# 202   6.512986e-08        29.858479   Q164746  The Wall Street Journal
# 459   3.942560e-09        29.747366  Q2129720         Gujarat Samachar
# 559   3.942560e-09        21.693314  Q2129720         Gujarat Samachar
# 704   4.834308e-08        38.062836  Q1023924               CNN-News18
# 723   4.171684e-08        23.440456    Q39681                USA Today
# 828   4.171684e-08        20.303715    Q39681                USA Today
# 841   1.195404e-08        15.794498   Q208875                  The Sun
# 1020  2.522555e-08        34.685140   Q483903       The Joong-ang Ilbo
# 1671  2.114644e-08        35.003716    Q46807       The Times of India
# 1771  2.114644e-08        21.693314    Q46807       The Times of India
# 1820  3.716594e-09        15.111079  Q3214299                 Il Globo
# 1919  4.931576e-06        12.792505  Q6735687              Mail Online
# 1940  4.931576e-06        21.693314  Q6735687              Mail Online
# 1941  4.893515e-09        41.596375  Q2732186        Malayala Manorama
# 2041  4.893515e-09        21.693314  Q2732186        Malayala Manorama
# 2042  3.539613e-09        21.800833  Q3246100                Dinamalar
# 2063  3.539613e-09        21.693314  Q3246100                Dinamalar
#
#       evaluation_label  monge_elkan  des_cont_jaccard  jaro_winkler  \
# 0                    1     1.000000               0.0      1.000000
# 100                  1     1.000000               0.0      1.000000
# 101                  1     1.000000               0.0      1.000000
# 201                  1     1.000000               0.0      1.000000
# 202                  1     0.899306               0.0      0.746377
# 459                  1     1.000000               0.0      1.000000
# 559                  1     1.000000               0.0      1.000000
# 704                  1     0.470833               0.0      0.483333
# 723                  1     1.000000               0.0      1.000000
# 828                  1     1.000000               0.0      1.000000
# 841                  1     1.000000               0.0      1.000000
# 1020                 1     0.637037               0.0      0.878307
# 1671                 1     0.961111               0.0      0.847619
# 1771                 1     0.961111               0.0      0.847619
# 1820                 1     0.891667               0.0      0.550000
# 1919                 1     0.608796               0.0      0.603367
# 1940                 1     0.608796               0.0      0.603367
# 1941                 1     1.000000               0.0      1.000000
# 2041                 1     1.000000               0.0      1.000000
# 2042                 1     1.000000               0.0      1.000000
# 2063                 1     1.000000               0.0      1.000000
#
#       graph-embedding-score  singleton  reciprocal_rank  num_char  num_tokens  \
# 0                  0.773640          0         0.250000        13           2
# 100                0.773640          1         0.200000        13           2
# 101                0.730027          0         0.090909        14           2
# 201                0.730027          1         0.083333        14           2
# 202                0.747756          0         0.333333        23           4
# 459                0.768198          0         0.500000        16           2
# 559                0.768198          1         0.333333        16           2
# 704                0.688494          0         0.500000        10           1
# 723                0.718286          0         0.250000         9           2
# 828                0.718286          0         0.200000         9           2
# 841                0.752667          0         0.200000         7           2
# 1020               0.643378          0         0.142857        18           3
# 1671               0.759303          0         0.200000        18           4
# 1771               0.759303          1         0.166667        18           4
# 1820               0.615701          0         0.047619         8           2
# 1919               0.721735          0         0.500000        11           2
# 1940               0.721735          1         0.333333        11           2
# 1941               0.757605          0         0.333333        17           2
# 2041               0.757605          1         0.250000        17           2
# 2042               0.730930          0         1.000000         9           1
# 2063               0.730930          1         0.500000         9           1
#
#       class_count_tf_idf_score  property_count_tf_idf_score  \
# 0                     0.252959                     0.119233
# 100                   0.252959                     0.119233
# 101                   0.276277                     0.157553
# 201                   0.276277                     0.157553
# 202                   0.276277                     0.421653
# 459                   0.400916                     0.167257
# 559                   0.400916                     0.167257
# 704                   0.173605                     0.094764
# 723                   0.276277                     0.351597
# 828                   0.276277                     0.351597
# 841                   0.276277                     0.213770
# 1020                  0.252959                     0.114359
# 1671                  0.252959                     0.241219
# 1771                  0.252959                     0.241219
# 1820                  0.110739                     0.058200
# 1919                  0.831549                     0.064644
# 1940                  0.831549                     0.064644
# 1941                  0.276277                     0.105934
# 2041                  0.276277                     0.105934
# 2042                  0.252959                     0.122606
# 2063                  0.252959                     0.122606
#
#       lof-graph-embedding-score  is_lof  lof-reciprocal-rank  \
# 0                      0.878575      -1             1.000000
# 100                    0.878575       1             0.500000
# 101                    0.821949      -1             0.200000
# 201                    0.821949       1             0.166667
# 202                    0.638817      -1             0.090909
# 459                    0.819080      -1             1.000000
# 559                    0.819080       1             0.500000
# 704                    0.677521      -1             0.500000
# 723                    0.652207      -1             0.142857
# 828                    0.652207      -1             0.125000
# 841                    0.708832      -1             0.034483
# 1020                   0.674065      -1             0.250000
# 1671                   0.776146      -1             0.200000
# 1771                   0.776146       1             0.166667
# 1820                   0.596655      -1             0.071429
# 1919                   0.587158      -1             0.111111
# 1940                   0.587158      -1             0.100000
# 1941                   0.804856      -1             0.500000
# 2041                   0.804856       1             0.333333
# 2042                   0.787062      -1             1.000000
# 2063                   0.787062       1             0.500000
#
#       lof_class_count_tf_idf_score  lof_property_count_tf_idf_score
# 0                         0.630953                         0.401334
# 100                       0.630953                         0.401334
# 101                       0.689114                         0.530315
# 201                       0.689114                         0.530315
# 202                       0.689114                         0.881520
# 459                       1.000000                         0.562977
# 559                       1.000000                         0.562977
# 704                       0.334006                         0.234974
# 723                       0.689114                         0.934676
# 828                       0.689114                         0.934676
# 841                       0.689114                         0.594610
# 1020                      0.630953                         0.367842
# 1671                      0.630953                         0.811931
# 1771                      0.630953                         0.811931
# 1820                      0.276216                         0.195900
# 1919                      0.630953                         0.195417
# 1940                      0.630953                         0.195417
# 1941                      0.689114                         0.356569
# 2041                      0.689114                         0.356569
# 2042                      0.630953                         0.412685
# 2063                      0.630953                         0.412685

# %%
final_feature_df.sort_values(by=['class_count_tf_idf_score'], ascending=False)['evaluation_label'].head(10)
# Out:
# 362     1
# 458     1
# 940    -1
# 1751   -1
# 1750   -1
# 1260    0
# 1447    0
# 1940    1
# 1687   -1
# 1919    1
# Name: evaluation_label, dtype: int64

# %%
final_feature_df.sort_values(by=['lof_class_count_tf_idf_score'], ascending=False)['evaluation_label'].head(10)
# Out:
# 559     1
# 459     1
# 458     1
# 362     1
# 1821   -1
# 1127    0
# 529    -1
# 286    -1
# 835    -1
# 723     1
# Name: evaluation_label, dtype: int64

# %%
final_feature_df['class_count_tf_idf_score'].max()
# Out:
# 0.8523632229755529

# %%
# final_feature_df[final_feature_df['evaluation_label'] == 1].loc[:, [
#     'cos_property_count_tf_idf_score', 'lof_property_count_tf_idf_score',
#     'cos_class_count_tf_idf_score', 'lof_class_count_tf_idf_score'
# ]]

# %%
# final_feature_df[final_feature_df['evaluation_label'] == 1].loc[:, [
#     'cos_class_count_tf_idf_score_tf', 'cos_class_count_tf_idf_score_idf',
#     'lof_class_count_tf_idf_score_tf', 'lof_class_count_tf_idf_score_idf'
# ]]

# %%
# final_feature_df[final_feature_df['evaluation_label'] == 1].loc[:, [
#     'cos_property_count_tf_idf_score_tf', 'cos_property_count_tf_idf_score_idf',
#     'lof_property_count_tf_idf_score_tf', 'lof_property_count_tf_idf_score_idf'
# ]]

# %% [markdown]
# ### Evaluation of lof-graph-embedding-score
# - baseline: graph-embedding-score (centroid-of-singleton)

# %%
# use top 1/5 accuracy
def embedding_eval(eval_file):
    assert "graph-embedding-score" in eval_file
    assert "lof-graph-embedding-score" in eval_file
    
    cos_top1_count = 0
    cos_top5_count = 0
    lof_top1_count = 0
    lof_top5_count = 0
    all_count = 0
    
    for ((col, row), group) in eval_file.groupby(['column', 'row']):
        all_count += 1
        
        # sort by centroid-of-singleton embedding score
        eval_labels = group.sort_values(by=['graph-embedding-score'], ascending=False)['evaluation_label']
        if eval_labels.iloc[0] == 1:
            cos_top1_count += 1
        if 1 in eval_labels.iloc[:5].values:
            cos_top5_count += 1
            
        # sort by centroid-of-lof embedding score
        eval_labels = group.sort_values(by=['lof-graph-embedding-score'], ascending=False)['evaluation_label']
        if eval_labels.iloc[0] == 1:
            lof_top1_count += 1
        if 1 in eval_labels.iloc[:5].values:
            lof_top5_count += 1
    
    return {
        'cos_top1_accuracy': cos_top1_count / all_count, 
        'cos_top5_accuracy': cos_top5_count / all_count, 
        'lof_top1_accuracy': lof_top1_count / all_count, 
        'lof_top5_accuracy': lof_top5_count / all_count,
        'all_count': all_count
    }

# %%
res_top_accuracy = {}
for fid in file_ids:
    final_df = pd.read_csv(f"{HOME_DIR}/merged-lof-score/{fid}.csv")
    res_top_accuracy[fid] = embedding_eval(final_df)
res_top_accuracy
# Out:
# {'69537082_0_7789694313271016902': {'cos_top1_accuracy': 0.4560669456066946,
#   'cos_top5_accuracy': 0.7154811715481172,
#   'lof_top1_accuracy': 0.8493723849372385,
#   'lof_top5_accuracy': 0.9414225941422594,
#   'all_count': 239},
#  '60319454_0_3938426910282115527': {'cos_top1_accuracy': 0.2978723404255319,
#   'cos_top5_accuracy': 0.5957446808510638,
#   'lof_top1_accuracy': 0.46808510638297873,
#   'lof_top5_accuracy': 0.6595744680851063,
#   'all_count': 47},
#  '16767252_0_2409448375013995751': {'cos_top1_accuracy': 0.5681818181818182,
#   'cos_top5_accuracy': 0.8295454545454546,
#   'lof_top1_accuracy': 0.6477272727272727,
#   'lof_top5_accuracy': 0.8636363636363636,
#   'all_count': 88},
#  '84548468_0_5955155464119382182': {'cos_top1_accuracy': 0.48484848484848486,
#   'cos_top5_accuracy': 0.7878787878787878,
#   'lof_top1_accuracy': 0.5252525252525253,
#   'lof_top5_accuracy': 0.8181818181818182,
#   'all_count': 99},
#  '80588006_0_6965325215443683359': {'cos_top1_accuracy': 0.19047619047619047,
#   'cos_top5_accuracy': 0.5238095238095238,
#   'lof_top1_accuracy': 0.3333333333333333,
#   'lof_top5_accuracy': 0.47619047619047616,
#   'all_count': 21},
#  '39650055_5_7135804139753401681': {'cos_top1_accuracy': 0.34,
#   'cos_top5_accuracy': 0.66,
#   'lof_top1_accuracy': 0.31,
#   'lof_top5_accuracy': 0.66,
#   'all_count': 100},
#  '8468806_0_4382447409703007384': {'cos_top1_accuracy': 0.24545454545454545,
#   'cos_top5_accuracy': 0.5363636363636364,
#   'lof_top1_accuracy': 0.3181818181818182,
#   'lof_top5_accuracy': 0.5818181818181818,
#   'all_count': 110},
#  '1438042989043_35_20150728002309-00287-ip-10-236-191-2_875026214_2': {'cos_top1_accuracy': 0.0,
#   'cos_top5_accuracy': 0.0,
#   'lof_top1_accuracy': 0.0,
#   'lof_top5_accuracy': 0.0,
#   'all_count': 18},
#  '25404227_0_2240631045609013057': {'cos_top1_accuracy': 0.44,
#   'cos_top5_accuracy': 0.85,
#   'lof_top1_accuracy': 0.55,
#   'lof_top5_accuracy': 0.9,
#   'all_count': 100},
#  '63450419_0_8012592961815711786': {'cos_top1_accuracy': 0.0,
#   'cos_top5_accuracy': 0.02030456852791878,
#   'lof_top1_accuracy': 0.005076142131979695,
#   'lof_top5_accuracy': 0.02030456852791878,
#   'all_count': 197},
#  '53822652_0_5767892317858575530': {'cos_top1_accuracy': 0.5930232558139535,
#   'cos_top5_accuracy': 0.9093023255813953,
#   'lof_top1_accuracy': 0.6186046511627907,
#   'lof_top5_accuracy': 0.9,
#   'all_count': 430},
#  '22864497_0_8632623712684511496': {'cos_top1_accuracy': 0.376657824933687,
#   'cos_top5_accuracy': 0.7320954907161804,
#   'lof_top1_accuracy': 0.3713527851458886,
#   'lof_top5_accuracy': 0.7400530503978779,
#   'all_count': 377},
#  '37856682_0_6818907050314633217': {'cos_top1_accuracy': 0.42028985507246375,
#   'cos_top5_accuracy': 0.7101449275362319,
#   'lof_top1_accuracy': 0.7536231884057971,
#   'lof_top5_accuracy': 0.9311594202898551,
#   'all_count': 276},
#  '26310680_0_5150772059999313798': {'cos_top1_accuracy': 0.0,
#   'cos_top5_accuracy': 0.0,
#   'lof_top1_accuracy': 0.0,
#   'lof_top5_accuracy': 0.0,
#   'all_count': 273},
#  '29414811_12_251152470253168163': {'cos_top1_accuracy': 0.25,
#   'cos_top5_accuracy': 0.4166666666666667,
#   'lof_top1_accuracy': 0.16666666666666666,
#   'lof_top5_accuracy': 0.375,
#   'all_count': 24},
#  '1438042986423_95_20150728002306-00125-ip-10-236-191-2_88435628_5': {'cos_top1_accuracy': 0.375,
#   'cos_top5_accuracy': 0.375,
#   'lof_top1_accuracy': 0.0,
#   'lof_top5_accuracy': 0.0,
#   'all_count': 8},
#  '39107734_2_2329160387535788734': {'cos_top1_accuracy': 0.44,
#   'cos_top5_accuracy': 0.78,
#   'lof_top1_accuracy': 0.38,
#   'lof_top5_accuracy': 0.8,
#   'all_count': 50},
#  '40534006_0_4617468856744635526': {'cos_top1_accuracy': 0.5641025641025641,
#   'cos_top5_accuracy': 0.9743589743589743,
#   'lof_top1_accuracy': 0.5384615384615384,
#   'lof_top5_accuracy': 0.9230769230769231,
#   'all_count': 39},
#  '90196673_0_5458330029110291950': {'cos_top1_accuracy': 0.002320185614849188,
#   'cos_top5_accuracy': 0.03480278422273782,
#   'lof_top1_accuracy': 0.18793503480278423,
#   'lof_top5_accuracy': 0.4245939675174014,
#   'all_count': 431},
#  '24036779_0_5608105867560183058': {'cos_top1_accuracy': 0.012048192771084338,
#   'cos_top5_accuracy': 0.060240963855421686,
#   'lof_top1_accuracy': 0.927710843373494,
#   'lof_top5_accuracy': 0.927710843373494,
#   'all_count': 83},
#  '41480166_0_6681239260286218499': {'cos_top1_accuracy': 0.20089285714285715,
#   'cos_top5_accuracy': 0.45089285714285715,
#   'lof_top1_accuracy': 0.23660714285714285,
#   'lof_top5_accuracy': 0.48214285714285715,
#   'all_count': 224},
#  '1438042989018_40_20150728002309-00067-ip-10-236-191-2_57714692_2': {'cos_top1_accuracy': 0.0,
#   'cos_top5_accuracy': 0.0,
#   'lof_top1_accuracy': 0.0,
#   'lof_top5_accuracy': 0.0,
#   'all_count': 6},
#  '77694908_0_6083291340991074532': {'cos_top1_accuracy': 0.42,
#   'cos_top5_accuracy': 0.81,
#   'lof_top1_accuracy': 0.63,
#   'lof_top5_accuracy': 0.89,
#   'all_count': 100},
#  '20135078_0_7570343137119682530': {'cos_top1_accuracy': 0.52,
#   'cos_top5_accuracy': 0.77,
#   'lof_top1_accuracy': 0.69,
#   'lof_top5_accuracy': 0.89,
#   'all_count': 100},
#  '35188621_0_6058553107571275232': {'cos_top1_accuracy': 0.4778761061946903,
#   'cos_top5_accuracy': 0.8761061946902655,
#   'lof_top1_accuracy': 0.5575221238938053,
#   'lof_top5_accuracy': 0.8761061946902655,
#   'all_count': 113},
#  '54719588_0_8417197176086756912': {'cos_top1_accuracy': 0.4314516129032258,
#   'cos_top5_accuracy': 0.7943548387096774,
#   'lof_top1_accuracy': 0.4717741935483871,
#   'lof_top5_accuracy': 0.8306451612903226,
#   'all_count': 248},
#  '21245481_0_8730460088443117515': {'cos_top1_accuracy': 0.3033175355450237,
#   'cos_top5_accuracy': 0.5639810426540285,
#   'lof_top1_accuracy': 0.3175355450236967,
#   'lof_top5_accuracy': 0.5687203791469194,
#   'all_count': 211},
#  '71840765_0_6664391841933033844': {'cos_top1_accuracy': 0.9285714285714286,
#   'cos_top5_accuracy': 1.0,
#   'lof_top1_accuracy': 0.9285714285714286,
#   'lof_top5_accuracy': 1.0,
#   'all_count': 14},
#  '58891288_0_1117541047012405958': {'cos_top1_accuracy': 0.51,
#   'cos_top5_accuracy': 0.9,
#   'lof_top1_accuracy': 0.66,
#   'lof_top5_accuracy': 0.93,
#   'all_count': 100},
#  '39173938_0_7916056990138658530': {'cos_top1_accuracy': 0.61,
#   'cos_top5_accuracy': 0.88,
#   'lof_top1_accuracy': 0.69,
#   'lof_top5_accuracy': 0.9,
#   'all_count': 100},
#  '10579449_0_1681126353774891032': {'cos_top1_accuracy': 0.38095238095238093,
#   'cos_top5_accuracy': 0.47619047619047616,
#   'lof_top1_accuracy': 0.3333333333333333,
#   'lof_top5_accuracy': 0.42857142857142855,
#   'all_count': 21},
#  '33401079_0_9127583903019856402': {'cos_top1_accuracy': 0.0,
#   'cos_top5_accuracy': 0.0,
#   'lof_top1_accuracy': 0.0,
#   'lof_top5_accuracy': 0.011904761904761904,
#   'all_count': 84},
#  '21362676_0_6854186738074119688': {'cos_top1_accuracy': 0.55,
#   'cos_top5_accuracy': 0.9,
#   'lof_top1_accuracy': 0.54,
#   'lof_top5_accuracy': 0.89,
#   'all_count': 100},
#  '38428277_0_1311643810102462607': {'cos_top1_accuracy': 0.5398230088495575,
#   'cos_top5_accuracy': 0.8584070796460177,
#   'lof_top1_accuracy': 0.6371681415929203,
#   'lof_top5_accuracy': 0.9026548672566371,
#   'all_count': 113},
#  '9834884_0_3871985887467090123': {'cos_top1_accuracy': 0.1856763925729443,
#   'cos_top5_accuracy': 0.38726790450928383,
#   'lof_top1_accuracy': 0.20689655172413793,
#   'lof_top5_accuracy': 0.3925729442970822,
#   'all_count': 377},
#  '91959037_0_7907661684242014480': {'cos_top1_accuracy': 0.0728643216080402,
#   'cos_top5_accuracy': 0.3065326633165829,
#   'lof_top1_accuracy': 0.07035175879396985,
#   'lof_top5_accuracy': 0.30904522613065327,
#   'all_count': 398},
#  '46671561_0_6122315295162029872': {'cos_top1_accuracy': 0.4076086956521739,
#   'cos_top5_accuracy': 0.75,
#   'lof_top1_accuracy': 0.32608695652173914,
#   'lof_top5_accuracy': 0.6739130434782609,
#   'all_count': 184},
#  '50245608_0_871275842592178099': {'cos_top1_accuracy': 0.3174061433447099,
#   'cos_top5_accuracy': 0.6075085324232082,
#   'lof_top1_accuracy': 0.3890784982935154,
#   'lof_top5_accuracy': 0.6484641638225256,
#   'all_count': 293},
#  '53989675_0_8697482470743954630': {'cos_top1_accuracy': 0.0,
#   'cos_top5_accuracy': 0.038461538461538464,
#   'lof_top1_accuracy': 0.0,
#   'lof_top5_accuracy': 0.038461538461538464,
#   'all_count': 26},
#  '88523363_0_8180214313099580515': {'cos_top1_accuracy': 0.0017094017094017094,
#   'cos_top5_accuracy': 0.006837606837606838,
#   'lof_top1_accuracy': 0.0017094017094017094,
#   'lof_top5_accuracy': 0.010256410256410256,
#   'all_count': 585},
#  '29414811_13_8724394428539174350': {'cos_top1_accuracy': 0.3125,
#   'cos_top5_accuracy': 0.625,
#   'lof_top1_accuracy': 0.3125,
#   'lof_top5_accuracy': 0.5625,
#   'all_count': 16},
#  '9567241_0_5666388268510912770': {'cos_top1_accuracy': 0.047619047619047616,
#   'cos_top5_accuracy': 0.47619047619047616,
#   'lof_top1_accuracy': 0.14285714285714285,
#   'lof_top5_accuracy': 0.38095238095238093,
#   'all_count': 21},
#  '99070098_0_2074872741302696997': {'cos_top1_accuracy': 0.7102803738317757,
#   'cos_top5_accuracy': 0.9252336448598131,
#   'lof_top1_accuracy': 0.705607476635514,
#   'lof_top5_accuracy': 0.9252336448598131,
#   'all_count': 214},
#  '43237185_1_3636357855502246981': {'cos_top1_accuracy': 0.6538461538461539,
#   'cos_top5_accuracy': 0.7692307692307693,
#   'lof_top1_accuracy': 0.6153846153846154,
#   'lof_top5_accuracy': 0.8076923076923077,
#   'all_count': 26}}

# %%
top_accuracy_df = pd.DataFrame(res_top_accuracy)
top_accuracy_df = top_accuracy_df.transpose()
len(top_accuracy_df[top_accuracy_df['lof_top1_accuracy'] < top_accuracy_df['cos_top1_accuracy']]), \
len(top_accuracy_df[top_accuracy_df['lof_top5_accuracy'] < top_accuracy_df['cos_top5_accuracy']]), \
len(top_accuracy_df)
# Out:
# (12, 10, 44)

# %%
# visualize embedding-score difference
def highlight_greaterthan_1(x):
    if x.lof_top1_accuracy < x.cos_top1_accuracy:
        return ['background-color: yellow']*5
    else:
        return ['background-color: white']*5
    
top_accuracy_df.style.apply(highlight_greaterthan_1, axis=1)
# Out:
# <style  type="text/css" >
# #T_a6f67_row0_col0,#T_a6f67_row0_col1,#T_a6f67_row0_col2,#T_a6f67_row0_col3,#T_a6f67_row0_col4,#T_a6f67_row1_col0,#T_a6f67_row1_col1,#T_a6f67_row1_col2,#T_a6f67_row1_col3,#T_a6f67_row1_col4,#T_a6f67_row2_col0,#T_a6f67_row2_col1,#T_a6f67_row2_col2,#T_a6f67_row2_col3,#T_a6f67_row2_col4,#T_a6f67_row3_col0,#T_a6f67_row3_col1,#T_a6f67_row3_col2,#T_a6f67_row3_col3,#T_a6f67_row3_col4,#T_a6f67_row4_col0,#T_a6f67_row4_col1,#T_a6f67_row4_col2,#T_a6f67_row4_col3,#T_a6f67_row4_col4,#T_a6f67_row6_col0,#T_a6f67_row6_col1,#T_a6f67_row6_col2,#T_a6f67_row6_col3,#T_a6f67_row6_col4,#T_a6f67_row7_col0,#T_a6f67_row7_col1,#T_a6f67_row7_col2,#T_a6f67_row7_col3,#T_a6f67_row7_col4,#T_a6f67_row8_col0,#T_a6f67_row8_col1,#T_a6f67_row8_col2,#T_a6f67_row8_col3,#T_a6f67_row8_col4,#T_a6f67_row9_col0,#T_a6f67_row9_col1,#T_a6f67_row9_col2,#T_a6f67_row9_col3,#T_a6f67_row9_col4,#T_a6f67_row10_col0,#T_a6f67_row10_col1,#T_a6f67_row10_col2,#T_a6f67_row10_col3,#T_a6f67_row10_col4,#T_a6f67_row12_col0,#T_a6f67_row12_col1,#T_a6f67_row12_col2,#T_a6f67_row12_col3,#T_a6f67_row12_col4,#T_a6f67_row13_col0,#T_a6f67_row13_col1,#T_a6f67_row13_col2,#T_a6f67_row13_col3,#T_a6f67_row13_col4,#T_a6f67_row18_col0,#T_a6f67_row18_col1,#T_a6f67_row18_col2,#T_a6f67_row18_col3,#T_a6f67_row18_col4,#T_a6f67_row19_col0,#T_a6f67_row19_col1,#T_a6f67_row19_col2,#T_a6f67_row19_col3,#T_a6f67_row19_col4,#T_a6f67_row20_col0,#T_a6f67_row20_col1,#T_a6f67_row20_col2,#T_a6f67_row20_col3,#T_a6f67_row20_col4,#T_a6f67_row21_col0,#T_a6f67_row21_col1,#T_a6f67_row21_col2,#T_a6f67_row21_col3,#T_a6f67_row21_col4,#T_a6f67_row22_col0,#T_a6f67_row22_col1,#T_a6f67_row22_col2,#T_a6f67_row22_col3,#T_a6f67_row22_col4,#T_a6f67_row23_col0,#T_a6f67_row23_col1,#T_a6f67_row23_col2,#T_a6f67_row23_col3,#T_a6f67_row23_col4,#T_a6f67_row24_col0,#T_a6f67_row24_col1,#T_a6f67_row24_col2,#T_a6f67_row24_col3,#T_a6f67_row24_col4,#T_a6f67_row25_col0,#T_a6f67_row25_col1,#T_a6f67_row25_col2,#T_a6f67_row25_col3,#T_a6f67_row25_col4,#T_a6f67_row26_col0,#T_a6f67_row26_col1,#T_a6f67_row26_col2,#T_a6f67_row26_col3,#T_a6f67_row26_col4,#T_a6f67_row27_col0,#T_a6f67_row27_col1,#T_a6f67_row27_col2,#T_a6f67_row27_col3,#T_a6f67_row27_col4,#T_a6f67_row28_col0,#T_a6f67_row28_col1,#T_a6f67_row28_col2,#T_a6f67_row28_col3,#T_a6f67_row28_col4,#T_a6f67_row29_col0,#T_a6f67_row29_col1,#T_a6f67_row29_col2,#T_a6f67_row29_col3,#T_a6f67_row29_col4,#T_a6f67_row31_col0,#T_a6f67_row31_col1,#T_a6f67_row31_col2,#T_a6f67_row31_col3,#T_a6f67_row31_col4,#T_a6f67_row33_col0,#T_a6f67_row33_col1,#T_a6f67_row33_col2,#T_a6f67_row33_col3,#T_a6f67_row33_col4,#T_a6f67_row34_col0,#T_a6f67_row34_col1,#T_a6f67_row34_col2,#T_a6f67_row34_col3,#T_a6f67_row34_col4,#T_a6f67_row37_col0,#T_a6f67_row37_col1,#T_a6f67_row37_col2,#T_a6f67_row37_col3,#T_a6f67_row37_col4,#T_a6f67_row38_col0,#T_a6f67_row38_col1,#T_a6f67_row38_col2,#T_a6f67_row38_col3,#T_a6f67_row38_col4,#T_a6f67_row39_col0,#T_a6f67_row39_col1,#T_a6f67_row39_col2,#T_a6f67_row39_col3,#T_a6f67_row39_col4,#T_a6f67_row40_col0,#T_a6f67_row40_col1,#T_a6f67_row40_col2,#T_a6f67_row40_col3,#T_a6f67_row40_col4,#T_a6f67_row41_col0,#T_a6f67_row41_col1,#T_a6f67_row41_col2,#T_a6f67_row41_col3,#T_a6f67_row41_col4{
#             background-color:  white;
#         }#T_a6f67_row5_col0,#T_a6f67_row5_col1,#T_a6f67_row5_col2,#T_a6f67_row5_col3,#T_a6f67_row5_col4,#T_a6f67_row11_col0,#T_a6f67_row11_col1,#T_a6f67_row11_col2,#T_a6f67_row11_col3,#T_a6f67_row11_col4,#T_a6f67_row14_col0,#T_a6f67_row14_col1,#T_a6f67_row14_col2,#T_a6f67_row14_col3,#T_a6f67_row14_col4,#T_a6f67_row15_col0,#T_a6f67_row15_col1,#T_a6f67_row15_col2,#T_a6f67_row15_col3,#T_a6f67_row15_col4,#T_a6f67_row16_col0,#T_a6f67_row16_col1,#T_a6f67_row16_col2,#T_a6f67_row16_col3,#T_a6f67_row16_col4,#T_a6f67_row17_col0,#T_a6f67_row17_col1,#T_a6f67_row17_col2,#T_a6f67_row17_col3,#T_a6f67_row17_col4,#T_a6f67_row30_col0,#T_a6f67_row30_col1,#T_a6f67_row30_col2,#T_a6f67_row30_col3,#T_a6f67_row30_col4,#T_a6f67_row32_col0,#T_a6f67_row32_col1,#T_a6f67_row32_col2,#T_a6f67_row32_col3,#T_a6f67_row32_col4,#T_a6f67_row35_col0,#T_a6f67_row35_col1,#T_a6f67_row35_col2,#T_a6f67_row35_col3,#T_a6f67_row35_col4,#T_a6f67_row36_col0,#T_a6f67_row36_col1,#T_a6f67_row36_col2,#T_a6f67_row36_col3,#T_a6f67_row36_col4,#T_a6f67_row42_col0,#T_a6f67_row42_col1,#T_a6f67_row42_col2,#T_a6f67_row42_col3,#T_a6f67_row42_col4,#T_a6f67_row43_col0,#T_a6f67_row43_col1,#T_a6f67_row43_col2,#T_a6f67_row43_col3,#T_a6f67_row43_col4{
#             background-color:  yellow;
#         }</style><table id="T_a6f67_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >cos_top1_accuracy</th>        <th class="col_heading level0 col1" >cos_top5_accuracy</th>        <th class="col_heading level0 col2" >lof_top1_accuracy</th>        <th class="col_heading level0 col3" >lof_top5_accuracy</th>        <th class="col_heading level0 col4" >all_count</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a6f67_level0_row0" class="row_heading level0 row0" >69537082_0_7789694313271016902</th>
#                         <td id="T_a6f67_row0_col0" class="data row0 col0" >0.456067</td>
#                         <td id="T_a6f67_row0_col1" class="data row0 col1" >0.715481</td>
#                         <td id="T_a6f67_row0_col2" class="data row0 col2" >0.849372</td>
#                         <td id="T_a6f67_row0_col3" class="data row0 col3" >0.941423</td>
#                         <td id="T_a6f67_row0_col4" class="data row0 col4" >239.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_a6f67_level0_row1" class="row_heading level0 row1" >60319454_0_3938426910282115527</th>
#                         <td id="T_a6f67_row1_col0" class="data row1 col0" >0.297872</td>
#                         <td id="T_a6f67_row1_col1" class="data row1 col1" >0.595745</td>
#                         <td id="T_a6f67_row1_col2" class="data row1 col2" >0.468085</td>
#                         <td id="T_a6f67_row1_col3" class="data row1 col3" >0.659574</td>
#                         <td id="T_a6f67_row1_col4" class="data row1 col4" >47.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_a6f67_level0_row2" class="row_heading level0 row2" >16767252_0_2409448375013995751</th>
#                         <td id="T_a6f67_row2_col0" class="data row2 col0" >0.568182</td>
#                         <td id="T_a6f67_row2_col1" class="data row2 col1" >0.829545</td>
#                         <td id="T_a6f67_row2_col2" class="data row2 col2" >0.647727</td>
#                         <td id="T_a6f67_row2_col3" class="data row2 col3" >0.863636</td>
#                         <td id="T_a6f67_row2_col4" class="data row2 col4" >88.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_a6f67_level0_row3" class="row_heading level0 row3" >84548468_0_5955155464119382182</th>
#                         <td id="T_a6f67_row3_col0" class="data row3 col0" >0.484848</td>
#                         <td id="T_a6f67_row3_col1" class="data row3 col1" >0.787879</td>
#                         <td id="T_a6f67_row3_col2" class="data row3 col2" >0.525253</td>
#                         <td id="T_a6f67_row3_col3" class="data row3 col3" >0.818182</td>
#                         <td id="T_a6f67_row3_col4" class="data row3 col4" >99.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_a6f67_level0_row4" class="row_heading level0 row4" >80588006_0_6965325215443683359</th>
#                         <td id="T_a6f67_row4_col0" class="data row4 col0" >0.190476</td>
#                         <td id="T_a6f67_row4_col1" class="data row4 col1" >0.523810</td>
#                         <td id="T_a6f67_row4_col2" class="data row4 col2" >0.333333</td>
#                         <td id="T_a6f67_row4_col3" class="data row4 col3" >0.476190</td>
#                         <td id="T_a6f67_row4_col4" class="data row4 col4" >21.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_a6f67_level0_row5" c
