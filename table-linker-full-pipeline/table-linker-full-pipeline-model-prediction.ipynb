# %%
import pandas as pd
import os
import glob
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

import numpy as np
import sklearn.metrics
from collections import defaultdict
import shutil
import pickle

pd.reset_option('all')
# Out:
# As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead.
#
# : boolean
#     use_inf_as_null had been deprecated and will be removed in a future
#     version. Use `use_inf_as_na` instead.

# %%
table = '/Users/rijulvohra/Documents/work/Novartis-ISI/table_linker_pipeline/'
table_name = 'mathematician.csv'
wikify_column_name = "Mathematician"

# %%
#intermediate files
canonical = 'canonical.csv'
candidates = "candidates.csv"
feature_votes = "feature_votes.csv"
score_file = "scores.csv"
model_name = 'rf_tuned_ranking.pkl'
temp_dir = os.path.join(os.path.join(table,'temp'))
table_path = os.path.join(table,table_name)
if not(os.path.exists(temp_dir)):
    os.makedirs(temp_dir)
embedding_file = os.path.join(temp_dir,'graph_embedding_transe.tsv')

# %% [markdown]
# ## Canonicalize

# %%
canonical_file = os.path.join(temp_dir,canonical)
# !tl canonicalize -c "$wikify_column_name" --add-context $table_path > $canonical_file

# %%
pd.read_csv(canonical_file, nrows = 10)
# Out:
#    column  row                      label  \
# 0       0    0            Keith F. Taylor
# 1       0    1        Anthony To-Ming Lau
# 2       0    2         Edmond E. Granirer
# 3       0    3               Harry Kesten
# 4       0    4                   Mark Kac
# 5       0    5             Hugo Steinhaus
# 6       0    6              David Hilbert
# 7       0    7  C. L. Ferdinand Lindemann
# 8       0    8             C. Felix Klein
# 9       0    9             Julius Pl?cker
#
#                                              context
# 0  1975|University of Alberta|Anthony To-Ming Lau...
# 1  1969|University of British Columbia|Edmond E. ...
# 2  1962|Hebrew University|Harry Kesten|On Amenabl...
# 3  1958|Cornell University|Mark Kac|Symmetric Ran...
# 4     1937|University of Lw?w|Hugo Steinhaus|unknown
# 5  1911|Georg-August-Universit?t G?ttingen|David ...
# 6  1885|Universit?t K?nigsberg|C. L. Ferdinand Li...
# 7  1873|Friedrich-Alexander-Universit?t Erlangen-...
# 8  1868|Rheinische Friedrich-Wilhelms-Universit?t...
# 9  1823|Philipps - Universit?t Marburg|Christian ...

# %% [markdown]
# ## Candidate Generation

# %%
# %%time
candidates_file = os.path.join(temp_dir,candidates)
aux_field = 'graph_embeddings_transe'
# !tl clean -c label -o label_clean $canonical_file \
        / --url http://ckg06:9200 --index wikidatadwd-augmented-02 get-fuzzy-augmented-matches -c label_clean \
        --auxiliary-fields $aux_field \
        --auxiliary-folder $temp_dir \
        / --url http://ckg06:9200 --index wikidatadwd-augmented-02 get-exact-matches \
        -c label_clean --auxiliary-fields $aux_field \
        --auxiliary-folder $temp_dir > $candidates_file
                
for field in aux_field.split(','):
    aux_list = []
    for f in glob.glob(f'{temp_dir}/*{aux_field}.tsv'):
        aux_list.append(pd.read_csv(f, sep='\t', dtype=object))
    aux_df = pd.concat(aux_list).drop_duplicates(subset=['qnode']).rename(columns={aux_field: 'embedding'})
    aux_df.to_csv(f'{temp_dir}/{aux_field}.tsv', sep='\t', index=False)
# Out:
# CPU times: user 2.36 s, sys: 810 ms, total: 3.17 s
# Wall time: 1min 28s

# %%
pd.read_csv(candidates_file,nrows = 10)
# Out:
#    column  row            label  \
# 0       0    0  Keith F. Taylor
# 1       0    0  Keith F. Taylor
# 2       0    0  Keith F. Taylor
# 3       0    0  Keith F. Taylor
# 4       0    0  Keith F. Taylor
# 5       0    0  Keith F. Taylor
# 6       0    0  Keith F. Taylor
# 7       0    0  Keith F. Taylor
# 8       0    0  Keith F. Taylor
# 9       0    0  Keith F. Taylor
#
#                                              context      label_clean  \
# 0  1975|University of Alberta|Anthony To-Ming Lau...  Keith F. Taylor
# 1  1975|University of Alberta|Anthony To-Ming Lau...  Keith F. Taylor
# 2  1975|University of Alberta|Anthony To-Ming Lau...  Keith F. Taylor
# 3  1975|University of Alberta|Anthony To-Ming Lau...  Keith F. Taylor
# 4  1975|University of Alberta|Anthony To-Ming Lau...  Keith F. Taylor
# 5  1975|University of Alberta|Anthony To-Ming Lau...  Keith F. Taylor
# 6  1975|University of Alberta|Anthony To-Ming Lau...  Keith F. Taylor
# 7  1975|University of Alberta|Anthony To-Ming Lau...  Keith F. Taylor
# 8  1975|University of Alberta|Anthony To-Ming Lau...  Keith F. Taylor
# 9  1975|University of Alberta|Anthony To-Ming Lau...  Keith F. Taylor
#
#         kg_id               kg_labels                kg_aliases  \
# 0   Q98543829          F Keith Taylor                       NaN
# 1   Q22087035            Keith Taylor                       NaN
# 2    Q6385100            Keith Taylor                       NaN
# 3    Q5079714    Charles Keith Taylor                       NaN
# 4  Q102164684  Keith Frederick Taylor                       NaN
# 5    Q1738098            Keith Taylor      Keith Richard Taylor
# 6    Q6385099            Keith Taylor                       NaN
# 7    Q6385101            Keith Taylor  Dennis More|Cadmus Evans
# 8   Q53567269         Keith A. Taylor                       NaN
# 9    Q5541266     George Keith Taylor                       NaN
#
#             method                                kg_descriptions  \
# 0  fuzzy-augmented                          UK election candidate
# 1  fuzzy-augmented                    British political scientist
# 2  fuzzy-augmented                                  Canadian poet
# 3  fuzzy-augmented                            Canadian politician
# 4  fuzzy-augmented               Ph.D. University of Alberta 1975
# 5  fuzzy-augmented                 British politician (born 1953)
# 6  fuzzy-augmented                       American football player
# 7  fuzzy-augmented  Australian science fiction and fantasy writer
# 8  fuzzy-augmented                                            NaN
# 9  fuzzy-augmented                    United States federal judge
#
#        pagerank  retrieval_score
# 0  3.539613e-09        23.373430
# 1  3.539613e-09        23.102688
# 2  3.539613e-09        22.614727
# 3  3.539613e-09        22.286064
# 4  1.120288e-08        22.128487
# 5  3.712462e-09        21.732487
# 6  3.539613e-09        21.732487
# 7  3.539613e-09        20.802166
# 8  3.539613e-09        19.758533
# 9  3.539613e-09        19.758533

# %% [markdown]
# ## Feature Voting

# %%
# %%time
feature_votes_file = os.path.join(temp_dir,feature_votes)
# !tl smallest-qnode-number $candidates_file \
    / string-similarity -i --method monge_elkan:tokenizer=word -o monge_elkan \
    / string-similarity -i --method jaccard:tokenizer=word -c kg_descriptions context -o des_cont_jaccard \
    / string-similarity -i --method jaro_winkler -o jaro_winkler \
    / feature-voting -c "pagerank,smallest_qnode_number,monge_elkan,des_cont_jaccard" > $feature_votes_file
# Out:
# CPU times: user 88.1 ms, sys: 38.5 ms, total: 127 ms
# Wall time: 5.39 s

# %%
pd.read_csv(feature_votes_file,nrows = 10)
# Out:
#    column  row            label  \
# 0       0    0  Keith F. Taylor
# 1       0    0  Keith F. Taylor
# 2       0    0  Keith F. Taylor
# 3       0    0  Keith F. Taylor
# 4       0    0  Keith F. Taylor
# 5       0    0  Keith F. Taylor
# 6       0    0  Keith F. Taylor
# 7       0    0  Keith F. Taylor
# 8       0    0  Keith F. Taylor
# 9       0    0  Keith F. Taylor
#
#                                              context      label_clean  \
# 0  1975|University of Alberta|Anthony To-Ming Lau...  Keith F. Taylor
# 1  1975|University of Alberta|Anthony To-Ming Lau...  Keith F. Taylor
# 2  1975|University of Alberta|Anthony To-Ming Lau...  Keith F. Taylor
# 3  1975|University of Alberta|Anthony To-Ming Lau...  Keith F. Taylor
# 4  1975|University of Alberta|Anthony To-Ming Lau...  Keith F. Taylor
# 5  1975|University of Alberta|Anthony To-Ming Lau...  Keith F. Taylor
# 6  1975|University of Alberta|Anthony To-Ming Lau...  Keith F. Taylor
# 7  1975|University of Alberta|Anthony To-Ming Lau...  Keith F. Taylor
# 8  1975|University of Alberta|Anthony To-Ming Lau...  Keith F. Taylor
# 9  1975|University of Alberta|Anthony To-Ming Lau...  Keith F. Taylor
#
#         kg_id               kg_labels                kg_aliases  \
# 0   Q98543829          F Keith Taylor                       NaN
# 1   Q22087035            Keith Taylor                       NaN
# 2    Q6385100            Keith Taylor                       NaN
# 3    Q5079714    Charles Keith Taylor                       NaN
# 4  Q102164684  Keith Frederick Taylor                       NaN
# 5    Q1738098            Keith Taylor      Keith Richard Taylor
# 6    Q6385099            Keith Taylor                       NaN
# 7    Q6385101            Keith Taylor  Dennis More|Cadmus Evans
# 8   Q53567269         Keith A. Taylor                       NaN
# 9    Q5541266     George Keith Taylor                       NaN
#
#             method                                kg_descriptions  \
# 0  fuzzy-augmented                          UK election candidate
# 1  fuzzy-augmented                    British political scientist
# 2  fuzzy-augmented                                  Canadian poet
# 3  fuzzy-augmented                            Canadian politician
# 4  fuzzy-augmented               Ph.D. University of Alberta 1975
# 5  fuzzy-augmented                 British politician (born 1953)
# 6  fuzzy-augmented                       American football player
# 7  fuzzy-augmented  Australian science fiction and fantasy writer
# 8  fuzzy-augmented                                            NaN
# 9  fuzzy-augmented                    United States federal judge
#
#        pagerank  retrieval_score  smallest_qnode_number  monge_elkan  \
# 0  3.539613e-09        23.373430                      0     0.950000
# 1  3.539613e-09        23.102688                      0     0.666667
# 2  3.539613e-09        22.614727                      0     0.666667
# 3  3.539613e-09        22.286064                      0     0.666667
# 4  1.120288e-08        22.128487                      0     0.845679
# 5  3.712462e-09        21.732487                      0     0.666667
# 6  3.539613e-09        21.732487                      0     0.666667
# 7  3.539613e-09        20.802166                      0     0.666667
# 8  3.539613e-09        19.758533                      0     0.888889
# 9  3.539613e-09        19.758533                      0     0.666667
#
#    des_cont_jaccard  jaro_winkler  votes
# 0               0.0      0.906349      1
# 1               0.0      0.960000      0
# 2               0.0      0.960000      0
# 3               0.0      0.605556      0
# 4               0.6      0.871082      1
# 5               0.0      0.960000      0
# 6               0.0      0.960000      0
# 7               0.0      0.960000      0
# 8               0.0      0.944762      0
# 9               0.0      0.773369      0

# %% [markdown]
# ## Compute Embedding Score using Column Vector Strategy

# %%
# %%time
f_embedding_file = os.path.join(temp_dir,'fuzzy_augmented_graph_embeddings_transe.tsv')
score = os.path.join(temp_dir,score_file)
# !tl score-using-embedding $feature_votes_file --column-vector-strategy centroid-of-singletons \
-o graph-embedding-score --embedding-file $f_embedding_file \
> $score
# Out:
# Qnodes to lookup: 2611
# Qnodes from file: 2571
# CPU times: user 24.7 ms, sys: 17.5 ms, total: 42.2 ms
# Wall time: 1.6 s

# %%
pd.read_csv(score,nrows = 10)
# Out:
#    column  row            label  \
# 0       0    0  Keith F. Taylor
# 1       0    0  Keith F. Taylor
# 2       0    0  Keith F. Taylor
# 3       0    0  Keith F. Taylor
# 4       0    0  Keith F. Taylor
# 5       0    0  Keith F. Taylor
# 6       0    0  Keith F. Taylor
# 7       0    0  Keith F. Taylor
# 8       0    0  Keith F. Taylor
# 9       0    0  Keith F. Taylor
#
#                                              context      label_clean  \
# 0  1975|University of Alberta|Anthony To-Ming Lau...  Keith F. Taylor
# 1  1975|University of Alberta|Anthony To-Ming Lau...  Keith F. Taylor
# 2  1975|University of Alberta|Anthony To-Ming Lau...  Keith F. Taylor
# 3  1975|University of Alberta|Anthony To-Ming Lau...  Keith F. Taylor
# 4  1975|University of Alberta|Anthony To-Ming Lau...  Keith F. Taylor
# 5  1975|University of Alberta|Anthony To-Ming Lau...  Keith F. Taylor
# 6  1975|University of Alberta|Anthony To-Ming Lau...  Keith F. Taylor
# 7  1975|University of Alberta|Anthony To-Ming Lau...  Keith F. Taylor
# 8  1975|University of Alberta|Anthony To-Ming Lau...  Keith F. Taylor
# 9  1975|University of Alberta|Anthony To-Ming Lau...  Keith F. Taylor
#
#         kg_id               kg_labels                kg_aliases  \
# 0   Q98543829          F Keith Taylor                       NaN
# 1   Q22087035            Keith Taylor                       NaN
# 2    Q6385100            Keith Taylor                       NaN
# 3    Q5079714    Charles Keith Taylor                       NaN
# 4  Q102164684  Keith Frederick Taylor                       NaN
# 5    Q1738098            Keith Taylor      Keith Richard Taylor
# 6    Q6385099            Keith Taylor                       NaN
# 7    Q6385101            Keith Taylor  Dennis More|Cadmus Evans
# 8   Q53567269         Keith A. Taylor                       NaN
# 9    Q5541266     George Keith Taylor                       NaN
#
#             method                                kg_descriptions  \
# 0  fuzzy-augmented                          UK election candidate
# 1  fuzzy-augmented                    British political scientist
# 2  fuzzy-augmented                                  Canadian poet
# 3  fuzzy-augmented                            Canadian politician
# 4  fuzzy-augmented               Ph.D. University of Alberta 1975
# 5  fuzzy-augmented                 British politician (born 1953)
# 6  fuzzy-augmented                       American football player
# 7  fuzzy-augmented  Australian science fiction and fantasy writer
# 8  fuzzy-augmented                                            NaN
# 9  fuzzy-augmented                    United States federal judge
#
#        pagerank  retrieval_score  smallest_qnode_number  monge_elkan  \
# 0  3.539613e-09        23.373430                      0     0.950000
# 1  3.539613e-09        23.102688                      0     0.666667
# 2  3.539613e-09        22.614727                      0     0.666667
# 3  3.539613e-09        22.286064                      0     0.666667
# 4  1.120288e-08        22.128487                      0     0.845679
# 5  3.712462e-09        21.732487                      0     0.666667
# 6  3.539613e-09        21.732487                      0     0.666667
# 7  3.539613e-09        20.802166                      0     0.666667
# 8  3.539613e-09        19.758533                      0     0.888889
# 9  3.539613e-09        19.758533                      0     0.666667
#
#    des_cont_jaccard  jaro_winkler  votes  graph-embedding-score
# 0               0.0      0.906349      1               0.178267
# 1               0.0      0.960000      0               0.357342
# 2               0.0      0.960000      0               0.416312
# 3               0.0      0.605556      0               0.407771
# 4               0.6      0.871082      1               0.266951
# 5               0.0      0.960000      0               0.296455
# 6               0.0      0.960000      0               0.310881
# 7               0.0      0.960000      0               0.332960
# 8               0.0      0.944762      0               0.312174
# 9               0.0      0.773369      0               0.375720

# %% [markdown]
# ## Generate Additional Features required for Model Prediction

# %%
## TODO: Need to add these features as cli commands in Table Linker

def create_singleton_feature(df):
        d = df[df['method'] == 'exact-match'].groupby(['column','row'])[['kg_id']].count()
        l = list(d[d['kg_id'] == 1].index)
        singleton_feat = []
        for i,row in df.iterrows():
            col_num,row_num = row['column'],row['row']
            if (col_num,row_num) in l:
                singleton_feat.append(1)
            else:
                singleton_feat.append(0)
        df['singleton'] = singleton_feat
        return df
        
def generate_reciprocal_rank(df):
    final_list = []
    grouped_obj = df.groupby(['row', 'column'])
    for cell in grouped_obj:
        reciprocal_rank = list(1/cell[1]['graph-embedding-score'].rank())
        cell[1]['reciprocal_rank'] = reciprocal_rank
        final_list.extend(cell[1].to_dict(orient='records'))
    odf = pd.DataFrame(final_list)
    return odf

features_df = pd.read_csv(score)
features_df = create_singleton_feature(features_df)
features_df['num_char'] = features_df['kg_labels'].apply(lambda x: len(x) if not(pd.isna(x)) else 0)
features_df['num_tokens'] = features_df['kg_labels'].apply(lambda x: len(x.split()) if not(pd.isna(x)) else 0)
features_df = generate_reciprocal_rank(features_df)
features_df.head()
# Out:
#    column  row            label  \
# 0       0    0  Keith F. Taylor
# 1       0    0  Keith F. Taylor
# 2       0    0  Keith F. Taylor
# 3       0    0  Keith F. Taylor
# 4       0    0  Keith F. Taylor
#
#                                              context      label_clean  \
# 0  1975|University of Alberta|Anthony To-Ming Lau...  Keith F. Taylor
# 1  1975|University of Alberta|Anthony To-Ming Lau...  Keith F. Taylor
# 2  1975|University of Alberta|Anthony To-Ming Lau...  Keith F. Taylor
# 3  1975|University of Alberta|Anthony To-Ming Lau...  Keith F. Taylor
# 4  1975|University of Alberta|Anthony To-Ming Lau...  Keith F. Taylor
#
#         kg_id               kg_labels kg_aliases           method  \
# 0   Q98543829          F Keith Taylor        NaN  fuzzy-augmented
# 1   Q22087035            Keith Taylor        NaN  fuzzy-augmented
# 2    Q6385100            Keith Taylor        NaN  fuzzy-augmented
# 3    Q5079714    Charles Keith Taylor        NaN  fuzzy-augmented
# 4  Q102164684  Keith Frederick Taylor        NaN  fuzzy-augmented
#
#                     kg_descriptions  ...  smallest_qnode_number  monge_elkan  \
# 0             UK election candidate  ...                      0     0.950000
# 1       British political scientist  ...                      0     0.666667
# 2                     Canadian poet  ...                      0     0.666667
# 3               Canadian politician  ...                      0     0.666667
# 4  Ph.D. University of Alberta 1975  ...                      0     0.845679
#
#    des_cont_jaccard  jaro_winkler  votes  graph-embedding-score  singleton  \
# 0               0.0      0.906349      1               0.178267          0
# 1               0.0      0.960000      0               0.357342          0
# 2               0.0      0.960000      0               0.416312          0
# 3               0.0      0.605556      0               0.407771          0
# 4               0.6      0.871082      1               0.266951          0
#
#    num_char  num_tokens  reciprocal_rank
# 0        14           3         0.125000
# 1        12           2         0.014706
# 2        12           2         0.011236
# 3        20           3         0.011905
# 4        22           3         0.037037
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Final Ranking Score Predicted by Model

# %%
features = ['pagerank','retrieval_score','monge_elkan',
            'des_cont_jaccard','jaro_winkler','graph-embedding-score',
            'singleton','num_char','num_tokens','reciprocal_rank']
final_score = os.path.join(temp_dir,'final_score.csv')
model = pickle.load(open(model_name,'rb'))
data = features_df[features]
predicted_score = model.predict(data)
features_df['model_prediction'] = predicted_score
features_df.to_csv(final_score,index=False)

# %%
pd.read_csv(final_score,nrows=10)
# Out:
#    column  row            label  \
# 0       0    0  Keith F. Taylor
# 1       0    0  Keith F. Taylor
# 2       0    0  Keith F. Taylor
# 3       0    0  Keith F. Taylor
# 4       0    0  Keith F. Taylor
# 5       0    0  Keith F. Taylor
# 6       0    0  Keith F. Taylor
# 7       0    0  Keith F. Taylor
# 8       0    0  Keith F. Taylor
# 9       0    0  Keith F. Taylor
#
#                                              context      label_clean  \
# 0  1975|University of Alberta|Anthony To-Ming Lau...  Keith F. Taylor
# 1  1975|University of Alberta|Anthony To-Ming Lau...  Keith F. Taylor
# 2  1975|University of Alberta|Anthony To-Ming Lau...  Keith F. Taylor
# 3  1975|University of Alberta|Anthony To-Ming Lau...  Keith F. Taylor
# 4  1975|University of Alberta|Anthony To-Ming Lau...  Keith F. Taylor
# 5  1975|University of Alberta|Anthony To-Ming Lau...  Keith F. Taylor
# 6  1975|University of Alberta|Anthony To-Ming Lau...  Keith F. Taylor
# 7  1975|University of Alberta|Anthony To-Ming Lau...  Keith F. Taylor
# 8  1975|University of Alberta|Anthony To-Ming Lau...  Keith F. Taylor
# 9  1975|University of Alberta|Anthony To-Ming Lau...  Keith F. Taylor
#
#         kg_id               kg_labels                kg_aliases  \
# 0   Q98543829          F Keith Taylor                       NaN
# 1   Q22087035            Keith Taylor                       NaN
# 2    Q6385100            Keith Taylor                       NaN
# 3    Q5079714    Charles Keith Taylor                       NaN
# 4  Q102164684  Keith Frederick Taylor                       NaN
# 5    Q1738098            Keith Taylor      Keith Richard Taylor
# 6    Q6385099            Keith Taylor                       NaN
# 7    Q6385101            Keith Taylor  Dennis More|Cadmus Evans
# 8   Q53567269         Keith A. Taylor                       NaN
# 9    Q5541266     George Keith Taylor                       NaN
#
#             method                                kg_descriptions  ...  \
# 0  fuzzy-augmented                          UK election candidate  ...
# 1  fuzzy-augmented                    British political scientist  ...
# 2  fuzzy-augmented                                  Canadian poet  ...
# 3  fuzzy-augmented                            Canadian politician  ...
# 4  fuzzy-augmented               Ph.D. University of Alberta 1975  ...
# 5  fuzzy-augmented                 British politician (born 1953)  ...
# 6  fuzzy-augmented                       American football player  ...
# 7  fuzzy-augmented  Australian science fiction and fantasy writer  ...
# 8  fuzzy-augmented                                            NaN  ...
# 9  fuzzy-augmented                    United States federal judge  ...
#
#    monge_elkan  des_cont_jaccard  jaro_winkler  votes  graph-embedding-score  \
# 0     0.950000               0.0      0.906349      1               0.178267
# 1     0.666667               0.0      0.960000      0               0.357342
# 2     0.666667               0.0      0.960000      0               0.416312
# 3     0.666667               0.0      0.605556      0               0.407771
# 4     0.845679               0.6      0.871082      1               0.266951
# 5     0.666667               0.0      0.960000      0               0.296455
# 6     0.666667               0.0      0.960000      0               0.310881
# 7     0.666667               0.0      0.960000      0               0.332960
# 8     0.888889               0.0      0.944762      0               0.312174
# 9     0.666667               0.0      0.773369      0               0.375720
#
#    singleton  num_char  num_tokens  reciprocal_rank  model_prediction
# 0          0        14           3         0.125000         -0.992000
# 1          0        12           2         0.014706         -0.387868
# 2          0        12           2         0.011236         -0.674692
# 3          0        20           3         0.011905         -0.804083
# 4          0        22           3         0.037037         -0.874778
# 5          0        12           2         0.025641         -0.607381
# 6          0        12           2         0.023256         -0.645166
# 7          0        12           2         0.017241         -0.649071
# 8          0        15           3         0.022727         -0.828452
# 9          0        19           3         0.013889         -0.759337
#
# [10 rows x 23 columns]

# %% [markdown]
# ## Get Top5 KG Links

# %%
linked_table_name = "topk-" + table_name
output_path = os.path.join(temp_dir,linked_table_name)
# !tl get-kg-links -c model_prediction -l label -k 5 $final_score > $output_path
pd.read_csv(output_path, nrows = 10)
# Out:
#    column  row                           label  \
# 0       0    0                 Keith F. Taylor
# 1       0    1             Anthony To-Ming Lau
# 2       0   10        Christian Ludwig Gerling
# 3       0   11            Carl Friedrich Gauss
# 4       0   12          Johann Friedrich Pfaff
# 5       0   13       Abraham Gotthelf Kaestner
# 6       0   14         Christian August Hausen
# 7       0   15         Christian Andreas Siber
# 8       0   16                Rudolf Lipschitz
# 9       0   17  Gustav Peter Lejeune Dirichlet
#
#                                                kg_id  \
# 0    Q22087035|Q1738098|Q6385099|Q100933635|Q6385101
# 1  Q93431753|Q5033813|Q15901790|Q102168953|Q24835859
# 2       Q1080895|Q1080897|Q72995|Q17521996|Q27580437
# 3        Q6722|Q1036512|Q87280488|Q1036458|Q18911469
# 4          Q77361|Q94917687|Q97264|Q123315|Q21223689
# 5      Q61813|Q24231370|Q4730637|Q94865315|Q24050378
# 6       Q1078821|Q21137947|Q1078815|Q4820676|Q214099
# 7    Q102233334|Q1078783|Q5109282|Q105604|Q102950252
# 8   Q77322|Q105466755|Q1782725|Q105466757|Q105466754
# 9          Q29193|Q2070240|Q975727|Q3750494|Q1254296
#
#                                             kg_label  \
# 0  Keith Taylor|Keith Taylor|Keith Taylor|Keith T...
# 1  Anthony To-Ming Lau|Canti Lau|Lau Wai Ming|Tin...
# 2  Christian Ludwig Gerling|Christian Ludwig Gerl...
# 3  Carl Friedrich Gauss|Carl Friedrich Gauss Priz...
# 4  Johann Friedrich Pfaff|Johann Friedrich Pfaff|...
# 5  Abraham Gotthelf Kästner|Kaestner, Abraham Got...
# 6  Christian August Hausen|Hausen, Christian Augu...
# 7  Christian Andreas Siber|Christian Andreas Sibe...
# 8  Rudolf Lipschitz|Henriette Lipschitz|Konstanti...
# 9  Johann Peter Gustav Lejeune Dirichlet|Florian ...
#
#                    ranking_score
# 0  -0.39|-0.61|-0.65|-0.65|-0.65
# 1  -0.01|-0.37|-0.62|-0.62|-0.63
# 2     0.04|-0.54|-0.6|-0.7|-0.72
# 3     0.08|0.03|-0.03|-0.4|-0.46
# 4   0.12|-0.15|-0.41|-0.59|-0.61
# 5     0.51|0.2|-0.06|-0.67|-0.67
# 6     0.1|-0.39|-0.54|-0.68|-0.7
# 7    0.73|0.08|-0.29|-0.35|-0.48
# 8    0.82|-0.74|-0.8|-0.81|-0.81
# 9    0.3|-0.12|-0.62|-0.65|-0.68

# %% [markdown]
# ## Join to Produce final result

# %%
final_output = 'linked-' + table_name
path = os.path.join(table,final_output)
# !tl join -f $table_path --csv -c ranking_score $output_path > $path

# %%
df = pd.read_csv(path)
df
# Out:
#                      Mathematician Year of PhD  \
# 0                  Keith F. Taylor        1975
# 1              Anthony To-Ming Lau        1969
# 2               Edmond E. Granirer        1962
# 3                     Harry Kesten        1958
# 4                         Mark Kac        1937
# 5                   Hugo Steinhaus        1911
# 6                    David Hilbert        1885
# 7        C. L. Ferdinand Lindemann        1873
# 8                   C. Felix Klein        1868
# 9                   Julius Pl?cker        1823
# 10        Christian Ludwig Gerling        1812
# 11            Carl Friedrich Gauss        1799
# 12          Johann Friedrich Pfaff        1786
# 13       Abraham Gotthelf Kaestner        1739
# 14         Christian August Hausen        1713
# 15         Christian Andreas Siber        1682
# 16                Rudolf Lipschitz        1853
# 17  Gustav Peter Lejeune Dirichlet        1827
# 18            Simeon Denis Poisson     unknown
# 19           Jean-Baptiste Fourier     unknown
# 20           Joseph Louis Lagrange     unknown
# 21                  Leonhard Euler        1726
# 22                Johann Bernoulli        1694
# 23                 Jacob Bernoulli     unknown
# 24                      Martin Ohm        1811
# 25    Karl Christian von Langsdorf     unknown
#
#                                  Granting Institution  \
# 0                               University of Alberta
# 1                      University of British Columbia
# 2                                   Hebrew University
# 3                                  Cornell University
# 4                                  University of Lw?w
# 5                  Georg-August-Universit?t G?ttingen
# 6                              Universit?t K?nigsberg
# 7   Friedrich-Alexander-Universit?t Erlangen-N?rnberg
# 8      Rheinische Friedrich-Wilhelms-Universit?t Bonn
# 9                      Philipps - Universit?t Marburg
# 10                 Georg-August-Universit?t G?ttingen
# 11                              Universit?t Helmstedt
# 12                 Georg-August-Universit?t G?ttingen
# 13                                Universit?t Leipzig
# 14         Martin-Luther-Universit?t Halle-Wittenberg
# 15         Martin-Luther-Universit?t Halle-Wittenberg
# 16                                 Universit?t Berlin
# 17     Rheinische Friedrich-Wilhelms-Universit?t Bonn
# 18                                            unknown
# 19                                            unknown
# 20                                            unknown
# 21                                  Universit?t Basel
# 22                                            unknown
# 23                                            unknown
# 24  Friedrich-Alexander-Universit?t Erlangen-N?rnberg
# 25                                            unknown
#
#                                   Supervisor  \
# 0                        Anthony To-Ming Lau
# 1                         Edmond E. Granirer
# 2                               Harry Kesten
# 3                                   Mark Kac
# 4                             Hugo Steinhaus
# 5                              David Hilbert
# 6                  C. L. Ferdinand Lindemann
# 7                             C. Felix Klein
# 8        Julius Pl?cker and Rudolf Lipschitz
# 9                          Christian Gerling
# 10                      Carl Friedrich Gauss
# 11                    Johann Friedrich Pfaff
# 12                 Abraham Gotthelf Kaestner
# 13                   Christian August Hausen
# 14                   Christian Andreas Siber
# 15                                   unknown
# 16           Gustav Dirichlet and Martin Ohm
# 17  Simeon Poisson and Jean-Baptiste Fourier
# 18                           Joseph Lagrange
# 19                     Joseph Louis Lagrange
# 20                            Leonhard Euler
# 21                          Johann Bernoulli
# 22                           Jacob Bernoulli
# 23                                   unknown
# 24              Karl Christian von Langsdorf
# 25                                   unknown
#
#                                                Thesis  \
# 0   The Structure of the Regular Representation of...
# 1                              Topological Semigroups
# 2   On Amenable Semigroups with a Finite Dimension...
# 3                    Symmetric Random Walks on Groups
# 4                                             unknown
# 5       Neue Anwendungen des Dirichlet'schen Prinzips
# 6   ?ber invariante Eigenschaften specieller bin?r...
# 7   ?ber unendlich kleine Bewegungen und ?ber Kraf...
# 8   ?ber die Transformation der allgemeinen Gleich...
# 9   Generalem analyeseos applicationem ad ea quae ...
# 10  Methodi proiectionis orthographicae usum ad ca...
# 11  Demonstratio nova theorematis omnem functionem...
# 12  Commentatio de ortibus et occasibus siderum ap...
# 13                   Theoria radicum in aequationibus
# 14                       Ex Philologicis De Asiarchis
# 15                    De stylo Novi Testamenti Graeco
# 16  Determinatio status magnetici viribus inducent...
# 17                                            unknown
# 18                                            unknown
# 19                                            unknown
# 20                                            unknown
# 21                                            unknown
# 22                                            unknown
# 23                                            unknown
# 24  De elevatione serierum infinitarum secundi ord...
# 25                                            unknown
#
#                                                 kg_id  \
# 0     Q22087035|Q1738098|Q6385099|Q100933635|Q6385101
# 1   Q93431753|Q5033813|Q15901790|Q102168953|Q24835859
# 2     Q102110100|Q2070883|Q5338859|Q36846677|Q5234312
# 3       Q635373|Q1663338|Q66311454|Q64482048|Q5666887
# 4     Q736380|Q104806349|Q203354|Q11770406|Q103865156
# 5      Q226072|Q95324688|Q12348999|Q4798943|Q95715292
# 6       Q41585|Q94846426|Q17044081|Q5234127|Q60232478
# 7          Q77203|Q5541739|Q95700945|Q21297020|Q95319
# 8     Q76641|Q27526592|Q58181951|Q67207502|Q104489551
# 9           Q57561|Q94787045|Q223433|Q37907|Q41503145
# 10       Q1080895|Q1080897|Q72995|Q17521996|Q27580437
# 11        Q6722|Q1036512|Q87280488|Q1036458|Q18911469
# 12          Q77361|Q94917687|Q97264|Q123315|Q21223689
# 13      Q61813|Q24231370|Q4730637|Q94865315|Q24050378
# 14       Q1078821|Q21137947|Q1078815|Q4820676|Q214099
# 15    Q102233334|Q1078783|Q5109282|Q105604|Q102950252
# 16   Q77322|Q105466755|Q1782725|Q105466757|Q105466754
# 17          Q29193|Q2070240|Q975727|Q3750494|Q1254296
# 18     Q190772|Q12256159|Q103847934|Q3131812|Q3131813
# 19       Q94370626|Q8772|Q85413030|Q3163830|Q98822217
# 20      Q80222|Q3185198|Q2037715|Q12345302|Q103852270
# 21       Q7604|Q89692800|Q5165791|Q7704960|Q103875595
# 22  Q27564227|Q27564446|Q21224294|Q103869820|Q1038...
# 23     Q122392|Q79251769|Q826719|Q79251719|Q103849298
# 24     Q707143|Q27585727|Q4674697|Q59387752|Q95191452
# 25             Q72538|Q62656|Q60810|Q21250144|Q111367
#
#                                              kg_label  \
# 0   Keith Taylor|Keith Taylor|Keith Taylor|Keith T...
# 1   Anthony To-Ming Lau|Canti Lau|Lau Wai Ming|Tin...
# 2   Edmond E. Granirer|Edmond Kramer|Edmond E. Cha...
# 3   Harry Kesten|Ingrid Kasten|Haim Kesten|Harry K...
# 4   Mark Kac|Mira Kac|Finnish markka|Markus Kac|Ka...
# 5   Hugo Steinhaus|Hugo Steinhauser|Hugo Steinhaue...
# 6   David Hilbert|David Leberecht Fürchtegott Hilb...
# 7   Ferdinand von Lindemann|George Lindemann|Anna ...
# 8   Felix Klein|Felix Klein|Felix Klein|C Klein|C ...
# 9   Julius Plücker|Julius Löcker|PL/I|.pl|Daniel J...
# 10  Christian Ludwig Gerling|Christian Ludwig Gerl...
# 11  Carl Friedrich Gauss|Carl Friedrich Gauss Priz...
# 12  Johann Friedrich Pfaff|Johann Friedrich Pfaff|...
# 13  Abraham Gotthelf Kästner|Kaestner, Abraham Got...
# 14  Christian August Hausen|Hausen, Christian Augu...
# 15  Christian Andreas Siber|Christian Andreas Sibe...
# 16  Rudolf Lipschitz|Henriette Lipschitz|Konstanti...
# 17  Johann Peter Gustav Lejeune Dirichlet|Florian ...
# 18  Siméon Denis Poisson|Denis Poisson|Poisson, Si...
# 19  Jean-Baptiste Fournier|Joseph Fourier|Jean-Bap...
# 20  Joseph-Louis Lagrange|Joseph Lagrange|Louis Jo...
# 21  Leonhard Euler|scientific work of Leonhard Eul...
# 22  Bernoulli, Johann II.|Bernoulli, Johann I.|Ber...
# 23  Jacob Bernoulli|Johann Jacob Bernoulli|Bernoul...
# 24  Martin Ohm|Ohm, Martin|acoustic ohm|Christian ...
# 25  Karl Christian von Langsdorf|Grigory Langsdorf...
#
#                             score
# 0   -0.39|-0.61|-0.65|-0.65|-0.65
# 1   -0.01|-0.37|-0.62|-0.62|-0.63
# 2    0.71|-0.81|-0.82|-0.84|-0.84
# 3   -0.07|-0.72|-0.73|-0.74|-0.74
# 4     0.59|-0.3|-0.44|-0.52|-0.57
# 5     0.89|-0.7|-0.71|-0.76|-0.82
# 6    0.52|-0.17|-0.36|-0.63|-0.66
# 7   -0.17|-0.76|-0.77|-0.78|-0.79
# 8    -0.61|-0.7|-0.71|-0.73|-0.73
# 9    0.02|-0.84|-0.86|-0.86|-0.87
# 10     0.04|-0.54|-0.6|-0.7|-0.72
# 11     0.08|0.03|-0.03|-0.4|-0.46
# 12   0.12|-0.15|-0.41|-0.59|-0.61
# 13     0.51|0.2|-0.06|-0.67|-0.67
# 14     0.1|-0.39|-0.54|-0.68|-0.7
# 15    0.73|0.08|-0.29|-0.35|-0.48
# 16    0.82|-0.74|-0.8|-0.81|-0.81
# 17    0.3|-0.12|-0.62|-0.65|-0.68
# 18  -0.43|-0.57|-0.78|-0.78|-0.79
# 19    0.03|-0.1|-0.12|-0.19|-0.48
# 20   -0.1|-0.44|-0.72|-0.74|-0.81
# 21    0.87|0.08|-0.11|-0.28|-0.32
# 22   -0.5|-0.52|-0.59|-0.77|-0.79
# 23   0.83|-0.11|-0.17|-0.27|-0.61
# 24   0.93|-0.55|-0.66|-0.74|-0.75
# 25     0.88|0.29|0.19|-0.29|-0.48

# %% [markdown]
# ## CleanUp temporary files

# %%
shutil.rmtree(temp_dir)
